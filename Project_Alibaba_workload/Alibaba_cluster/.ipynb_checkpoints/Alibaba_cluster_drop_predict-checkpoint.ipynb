# %%
from math import sqrt
import tensorflow as tf

import pandas as pd
from keras import Sequential
from keras.layers import LSTM, Dense, Dropout, Conv1D, GRU
from keras.losses import mean_squared_error
from numpy.core._multiarray_umath import concatenate
from sklearn.preprocessing import MinMaxScaler
import matplotlib.pyplot as plt

# supervised监督学习函数


def series_to_supervised(data, columns, n_in=1, n_out=1, dropnan=True):
    n_vars = 1 if isinstance(data, list) else data.shape[1]
    df = pd.DataFrame(data)
    cols, names = list(), list()
    # input sequence (t-n, ... t-1)
    for i in range(n_in, 0, -1):
        cols.append(df.shift(i))
        names += [('%s%d(t-%d)' % (columns[j], j + 1, i))
                  for j in range(n_vars)]
    # forecast sequence (t, t+1, ... t+n)
    for i in range(0, n_out):
        cols.append(df.shift(-i))
        if i == 0:
            names += [('%s%d(t)' % (columns[j], j + 1)) for j in range(n_vars)]
        else:
            names += [('%s%d(t+%d)' % (columns[j], j + 1, i))
                      for j in range(n_vars)]
    # put it all together
    agg = pd.concat(cols, axis=1)
    agg.columns = names
    # drop rows with NaN values
    if dropnan:
        clean_agg = agg.dropna()
    return clean_agg
    # return agg


dataset = pd.read_csv(
    'Machine_usage_groupby.csv')

dataset_columns = dataset.columns
values = dataset.values
print(dataset)

# 归一化处理
scaler = MinMaxScaler(feature_range=(0, 1))
scaled = scaler.fit_transform(values)


# 监督学习
reframed = series_to_supervised(scaled, dataset_columns, 1, 1)
values = reframed.values

# 学习与检测数据的划分
n_train_hours = 20000
train = values[:n_train_hours, :]
test = values[n_train_hours:, :]


# 监督学习结果划分
train_x, train_y = train[:, :-1], train[:, -1]
test_x, test_y = test[:, :-1], test[:, -1]



# 为了在LSTM中应用该数据，需要将其格式转化为3D format，即[Samples, timesteps, features]
train_X = train_x.reshape((train_x.shape[0], 1, train_x.shape[1]))
test_X = test_x.reshape((test_x.shape[0], 1, test_x.shape[1]))


model = Sequential()
model.add(Conv1D(filters=32, kernel_size=5,
                 strides=1, padding="causal",
                 activation="sigmoid"))
model.add(
    GRU(
        32,
        input_shape=(
            train_X.shape[1],
            train_X.shape[2]),
        return_sequences=True))
model.add(GRU(16, input_shape=(train_X.shape[1], train_X.shape[2])))
model.add(Dense(16, activation="relu"))
model.add(Dense(8, activation="relu"))
model.add(Dropout(0.2))
model.add(Dense(1))
model.compile(loss=tf.keras.losses.Huber(),
    optimizer='adam',
    metrics=["mse"])
history = model.fit(
    train_X,
    train_y,
    epochs=300,
    batch_size=72,
    validation_data=(
        test_X,
        test_y),
verbose = 2)
# Out:
#          Time  cpu_util_percent  ...  net_out  disk_usage_percent
# 0           0              12.0  ...    26.49                31.0
# 1         130              13.5  ...    28.63                 2.5
# 2         140               5.0  ...    18.12                 1.0
# 3         160              13.0  ...    30.09                 3.0
# 4         180               5.0  ...    18.12                 1.0
# ...       ...               ...  ...      ...                 ...
# 36211  691040              28.0  ...    41.75                 3.0
# 36212  691060              93.0  ...    38.37                 3.0
# 36213  691080              31.0  ...    35.73                 3.0
# 36214  691110              92.0  ...    38.37                 2.0
# 36215  691180              18.5  ...    38.47                 3.5
#
# [36216 rows x 6 columns]
# Train on 20000 samples, validate on 16215 samples
# Epoch 1/300
#  - 5s - loss: 0.0032 - mse: 0.0065 - val_loss: 0.0019 - val_mse: 0.0039
# Epoch 2/300
#  - 4s - loss: 0.0024 - mse: 0.0049 - val_loss: 0.0015 - val_mse: 0.0029
# Epoch 3/300
#  - 4s - loss: 0.0023 - mse: 0.0045 - val_loss: 0.0018 - val_mse: 0.0035
# Epoch 4/300
#  - 4s - loss: 0.0022 - mse: 0.0045 - val_loss: 0.0014 - val_mse: 0.0027
# Epoch 5/300
#  - 4s - loss: 0.0022 - mse: 0.0044 - val_loss: 0.0016 - val_mse: 0.0032
# Epoch 6/300
#  - 4s - loss: 0.0022 - mse: 0.0043 - val_loss: 0.0016 - val_mse: 0.0033
# Epoch 7/300
#  - 4s - loss: 0.0022 - mse: 0.0043 - val_loss: 0.0014 - val_mse: 0.0029
# Epoch 8/300
#  - 4s - loss: 0.0022 - mse: 0.0043 - val_loss: 0.0014 - val_mse: 0.0028
# Epoch 9/300
#  - 4s - loss: 0.0021 - mse: 0.0043 - val_loss: 0.0013 - val_mse: 0.0027
# Epoch 10/300
#  - 4s - loss: 0.0022 - mse: 0.0043 - val_loss: 0.0014 - val_mse: 0.0029
# Epoch 11/300
#  - 4s - loss: 0.0021 - mse: 0.0043 - val_loss: 0.0018 - val_mse: 0.0036
# Epoch 12/300
#  - 4s - loss: 0.0021 - mse: 0.0043 - val_loss: 0.0015 - val_mse: 0.0029
# Epoch 13/300
#  - 4s - loss: 0.0022 - mse: 0.0043 - val_loss: 0.0015 - val_mse: 0.0030
# Epoch 14/300
#  - 4s - loss: 0.0021 - mse: 0.0042 - val_loss: 0.0014 - val_mse: 0.0027
# Epoch 15/300
#  - 4s - loss: 0.0021 - mse: 0.0043 - val_loss: 0.0014 - val_mse: 0.0028
# Epoch 16/300
#  - 4s - loss: 0.0021 - mse: 0.0042 - val_loss: 0.0017 - val_mse: 0.0033
# Epoch 17/300
#  - 4s - loss: 0.0021 - mse: 0.0043 - val_loss: 0.0015 - val_mse: 0.0030
# Epoch 18/300
#  - 4s - loss: 0.0021 - mse: 0.0042 - val_loss: 0.0014 - val_mse: 0.0029
# Epoch 19/300
#  - 4s - loss: 0.0021 - mse: 0.0043 - val_loss: 0.0018 - val_mse: 0.0037
# Epoch 20/300
#  - 4s - loss: 0.0021 - mse: 0.0042 - val_loss: 0.0018 - val_mse: 0.0035
# Epoch 21/300
#  - 4s - loss: 0.0021 - mse: 0.0042 - val_loss: 0.0016 - val_mse: 0.0031
# Epoch 22/300
#  - 4s - loss: 0.0021 - mse: 0.0042 - val_loss: 0.0018 - val_mse: 0.0036
# Epoch 23/300
#  - 4s - loss: 0.0021 - mse: 0.0042 - val_loss: 0.0015 - val_mse: 0.0030
# Epoch 24/300
#  - 4s - loss: 0.0021 - mse: 0.0042 - val_loss: 0.0018 - val_mse: 0.0035
# Epoch 25/300
#  - 4s - loss: 0.0021 - mse: 0.0042 - val_loss: 0.0020 - val_mse: 0.0040
# Epoch 26/300
#  - 4s - loss: 0.0021 - mse: 0.0042 - val_loss: 0.0014 - val_mse: 0.0028
# Epoch 27/300
#  - 4s - loss: 0.0021 - mse: 0.0042 - val_loss: 0.0015 - val_mse: 0.0030
# Epoch 28/300
#  - 4s - loss: 0.0021 - mse: 0.0042 - val_loss: 0.0014 - val_mse: 0.0028
# Epoch 29/300
#  - 4s - loss: 0.0021 - mse: 0.0042 - val_loss: 0.0014 - val_mse: 0.0028
# Epoch 30/300
#  - 4s - loss: 0.0021 - mse: 0.0042 - val_loss: 0.0017 - val_mse: 0.0033
# Epoch 31/300
#  - 4s - loss: 0.0021 - mse: 0.0042 - val_loss: 0.0016 - val_mse: 0.0032
# Epoch 32/300
#  - 4s - loss: 0.0021 - mse: 0.0042 - val_loss: 0.0017 - val_mse: 0.0035
# Epoch 33/300
#  - 4s - loss: 0.0021 - mse: 0.0042 - val_loss: 0.0015 - val_mse: 0.0029
# Epoch 34/300
#  - 4s - loss: 0.0021 - mse: 0.0042 - val_loss: 0.0020 - val_mse: 0.0039
# Epoch 35/300
#  - 4s - loss: 0.0021 - mse: 0.0042 - val_loss: 0.0016 - val_mse: 0.0031
# Epoch 36/300
#  - 4s - loss: 0.0021 - mse: 0.0042 - val_loss: 0.0014 - val_mse: 0.0028
# Epoch 37/300
#  - 4s - loss: 0.0021 - mse: 0.0041 - val_loss: 0.0014 - val_mse: 0.0029
# Epoch 38/300
#  - 4s - loss: 0.0021 - mse: 0.0041 - val_loss: 0.0014 - val_mse: 0.0028
# Epoch 39/300
#  - 4s - loss: 0.0021 - mse: 0.0041 - val_loss: 0.0014 - val_mse: 0.0027
# Epoch 40/300
#  - 4s - loss: 0.0021 - mse: 0.0041 - val_loss: 0.0016 - val_mse: 0.0032
# Epoch 41/300
#  - 4s - loss: 0.0021 - mse: 0.0041 - val_loss: 0.0017 - val_mse: 0.0034
# Epoch 42/300
#  - 4s - loss: 0.0021 - mse: 0.0041 - val_loss: 0.0016 - val_mse: 0.0032
# Epoch 43/300
#  - 4s - loss: 0.0020 - mse: 0.0041 - val_loss: 0.0015 - val_mse: 0.0031
# Epoch 44/300
#  - 4s - loss: 0.0021 - mse: 0.0041 - val_loss: 0.0014 - val_mse: 0.0029
# Epoch 45/300
#  - 4s - loss: 0.0021 - mse: 0.0041 - val_loss: 0.0017 - val_mse: 0.0034
# Epoch 46/300
#  - 4s - loss: 0.0020 - mse: 0.0041 - val_loss: 0.0017 - val_mse: 0.0033
# Epoch 47/300
#  - 4s - loss: 0.0021 - mse: 0.0041 - val_loss: 0.0017 - val_mse: 0.0034
# Epoch 48/300
#  - 4s - loss: 0.0021 - mse: 0.0041 - val_loss: 0.0015 - val_mse: 0.0030
# Epoch 49/300
#  - 4s - loss: 0.0020 - mse: 0.0041 - val_loss: 0.0016 - val_mse: 0.0032
# Epoch 50/300
#  - 4s - loss: 0.0020 - mse: 0.0041 - val_loss: 0.0014 - val_mse: 0.0029
# Epoch 51/300
#  - 4s - loss: 0.0020 - mse: 0.0041 - val_loss: 0.0017 - val_mse: 0.0033
# Epoch 52/300
#  - 4s - loss: 0.0020 - mse: 0.0041 - val_loss: 0.0014 - val_mse: 0.0027
# Epoch 53/300
#  - 4s - loss: 0.0020 - mse: 0.0041 - val_loss: 0.0017 - val_mse: 0.0034
# Epoch 54/300
#  - 4s - loss: 0.0020 - mse: 0.0041 - val_loss: 0.0017 - val_mse: 0.0034
# Epoch 55/300
#  - 4s - loss: 0.0020 - mse: 0.0041 - val_loss: 0.0016 - val_mse: 0.0033
# Epoch 56/300
#  - 4s - loss: 0.0020 - mse: 0.0041 - val_loss: 0.0013 - val_mse: 0.0026
# Epoch 57/300
#  - 4s - loss: 0.0020 - mse: 0.0040 - val_loss: 0.0014 - val_mse: 0.0027
# Epoch 58/300
#  - 4s - loss: 0.0020 - mse: 0.0041 - val_loss: 0.0013 - val_mse: 0.0027
# Epoch 59/300
#  - 4s - loss: 0.0020 - mse: 0.0040 - val_loss: 0.0014 - val_mse: 0.0028
# Epoch 60/300
#  - 4s - loss: 0.0020 - mse: 0.0040 - val_loss: 0.0016 - val_mse: 0.0032
# Epoch 61/300
#  - 4s - loss: 0.0020 - mse: 0.0040 - val_loss: 0.0016 - val_mse: 0.0031
# Epoch 62/300
#  - 4s - loss: 0.0020 - mse: 0.0040 - val_loss: 0.0015 - val_mse: 0.0029
# Epoch 63/300
#  - 4s - loss: 0.0020 - mse: 0.0041 - val_loss: 0.0013 - val_mse: 0.0027
# Epoch 64/300
#  - 4s - loss: 0.0020 - mse: 0.0040 - val_loss: 0.0017 - val_mse: 0.0033
# Epoch 65/300
#  - 4s - loss: 0.0020 - mse: 0.0040 - val_loss: 0.0015 - val_mse: 0.0029
# Epoch 66/300
#  - 4s - loss: 0.0020 - mse: 0.0040 - val_loss: 0.0014 - val_mse: 0.0027
# Epoch 67/300
#  - 4s - loss: 0.0020 - mse: 0.0040 - val_loss: 0.0014 - val_mse: 0.0028
# Epoch 68/300
#  - 4s - loss: 0.0020 - mse: 0.0040 - val_loss: 0.0016 - val_mse: 0.0033
# Epoch 69/300
#  - 4s - loss: 0.0020 - mse: 0.0040 - val_loss: 0.0014 - val_mse: 0.0027
# Epoch 70/300
#  - 4s - loss: 0.0020 - mse: 0.0040 - val_loss: 0.0014 - val_mse: 0.0028
# Epoch 71/300
#  - 4s - loss: 0.0020 - mse: 0.0040 - val_loss: 0.0016 - val_mse: 0.0031
# Epoch 72/300
#  - 4s - loss: 0.0020 - mse: 0.0040 - val_loss: 0.0014 - val_mse: 0.0028
# Epoch 73/300
#  - 4s - loss: 0.0020 - mse: 0.0040 - val_loss: 0.0018 - val_mse: 0.0035
# Epoch 74/300
#  - 4s - loss: 0.0020 - mse: 0.0040 - val_loss: 0.0017 - val_mse: 0.0035
# Epoch 75/300
#  - 4s - loss: 0.0020 - mse: 0.0040 - val_loss: 0.0015 - val_mse: 0.0030
# Epoch 76/300
#  - 4s - loss: 0.0020 - mse: 0.0040 - val_loss: 0.0013 - val_mse: 0.0027
# Epoch 77/300
#  - 4s - loss: 0.0020 - mse: 0.0040 - val_loss: 0.0014 - val_mse: 0.0028
# Epoch 78/300
#  - 4s - loss: 0.0020 - mse: 0.0040 - val_loss: 0.0013 - val_mse: 0.0027
# Epoch 79/300
#  - 4s - loss: 0.0020 - mse: 0.0040 - val_loss: 0.0014 - val_mse: 0.0027
# Epoch 80/300
#  - 4s - loss: 0.0020 - mse: 0.0040 - val_loss: 0.0016 - val_mse: 0.0031
# Epoch 81/300
#  - 4s - loss: 0.0020 - mse: 0.0040 - val_loss: 0.0014 - val_mse: 0.0029
# Epoch 82/300
#  - 4s - loss: 0.0020 - mse: 0.0040 - val_loss: 0.0016 - val_mse: 0.0032
# Epoch 83/300
#  - 4s - loss: 0.0020 - mse: 0.0040 - val_loss: 0.0014 - val_mse: 0.0029
# Epoch 84/300
#  - 4s - loss: 0.0020 - mse: 0.0040 - val_loss: 0.0015 - val_mse: 0.0031
# Epoch 85/300
#  - 4s - loss: 0.0020 - mse: 0.0040 - val_loss: 0.0015 - val_mse: 0.0031
# Epoch 86/300
#  - 4s - loss: 0.0020 - mse: 0.0040 - val_loss: 0.0015 - val_mse: 0.0029
# Epoch 87/300
#  - 4s - loss: 0.0020 - mse: 0.0040 - val_loss: 0.0014 - val_mse: 0.0029
# Epoch 88/300
#  - 4s - loss: 0.0020 - mse: 0.0040 - val_loss: 0.0015 - val_mse: 0.0030
# Epoch 89/300
#  - 4s - loss: 0.0020 - mse: 0.0039 - val_loss: 0.0015 - val_mse: 0.0031
# Epoch 90/300
#  - 4s - loss: 0.0020 - mse: 0.0040 - val_loss: 0.0014 - val_mse: 0.0029
# Epoch 91/300
#  - 4s - loss: 0.0020 - mse: 0.0040 - val_loss: 0.0016 - val_mse: 0.0032
# Epoch 92/300
#  - 4s - loss: 0.0020 - mse: 0.0040 - val_loss: 0.0015 - val_mse: 0.0029
# Epoch 93/300
#  - 4s - loss: 0.0020 - mse: 0.0039 - val_loss: 0.0016 - val_mse: 0.0033
# Epoch 94/300
#  - 4s - loss: 0.0020 - mse: 0.0040 - val_loss: 0.0015 - val_mse: 0.0030
# Epoch 95/300
#  - 4s - loss: 0.0020 - mse: 0.0040 - val_loss: 0.0018 - val_mse: 0.0035
# Epoch 96/300
#  - 4s - loss: 0.0020 - mse: 0.0040 - val_loss: 0.0015 - val_mse: 0.0030
# Epoch 97/300
#  - 4s - loss: 0.0020 - mse: 0.0040 - val_loss: 0.0014 - val_mse: 0.0028
# Epoch 98/300
#  - 4s - loss: 0.0020 - mse: 0.0040 - val_loss: 0.0013 - val_mse: 0.0026
# Epoch 99/300
#  - 4s - loss: 0.0020 - mse: 0.0039 - val_loss: 0.0015 - val_mse: 0.0030
# Epoch 100/300
#  - 4s - loss: 0.0020 - mse: 0.0040 - val_loss: 0.0013 - val_mse: 0.0027
# Epoch 101/300
#  - 4s - loss: 0.0020 - mse: 0.0039 - val_loss: 0.0015 - val_mse: 0.0031
# Epoch 102/300
#  - 4s - loss: 0.0020 - mse: 0.0040 - val_loss: 0.0014 - val_mse: 0.0029
# Epoch 103/300
#  - 4s - loss: 0.0020 - mse: 0.0040 - val_loss: 0.0014 - val_mse: 0.0027
# Epoch 104/300
#  - 4s - loss: 0.0020 - mse: 0.0039 - val_loss: 0.0016 - val_mse: 0.0032
# Epoch 105/300
#  - 4s - loss: 0.0020 - mse: 0.0040 - val_loss: 0.0014 - val_mse: 0.0027
# Epoch 106/300
#  - 4s - loss: 0.0020 - mse: 0.0040 - val_loss: 0.0015 - val_mse: 0.0030
# Epoch 107/300
#  - 4s - loss: 0.0020 - mse: 0.0040 - val_loss: 0.0014 - val_mse: 0.0028
# Epoch 108/300
#  - 4s - loss: 0.0020 - mse: 0.0040 - val_loss: 0.0014 - val_mse: 0.0028
# Epoch 109/300
#  - 4s - loss: 0.0020 - mse: 0.0040 - val_loss: 0.0015 - val_mse: 0.0029
# Epoch 110/300
#  - 4s - loss: 0.0020 - mse: 0.0040 - val_loss: 0.0014 - val_mse: 0.0028
# Epoch 111/300
#  - 4s - loss: 0.0020 - mse: 0.0040 - val_loss: 0.0016 - val_mse: 0.0032
# Epoch 112/300
#  - 4s - loss: 0.0020 - mse: 0.0039 - val_loss: 0.0015 - val_mse: 0.0031
# Epoch 113/300
#  - 4s - loss: 0.0020 - mse: 0.0039 - val_loss: 0.0014 - val_mse: 0.0028
# Epoch 114/300
#  - 4s - loss: 0.0020 - mse: 0.0040 - val_loss: 0.0013 - val_mse: 0.0027
# Epoch 115/300
#  - 4s - loss: 0.0020 - mse: 0.0039 - val_loss: 0.0015 - val_mse: 0.0031
# Epoch 116/300
#  - 4s - loss: 0.0020 - mse: 0.0039 - val_loss: 0.0014 - val_mse: 0.0028
# Epoch 117/300
#  - 4s - loss: 0.0020 - mse: 0.0040 - val_loss: 0.0013 - val_mse: 0.0027
# Epoch 118/300
#  - 4s - loss: 0.0020 - mse: 0.0039 - val_loss: 0.0015 - val_mse: 0.0031
# Epoch 119/300
#  - 4s - loss: 0.0020 - mse: 0.0039 - val_loss: 0.0013 - val_mse: 0.0027
# Epoch 120/300
#  - 4s - loss: 0.0020 - mse: 0.0039 - val_loss: 0.0014 - val_mse: 0.0029
# Epoch 121/300
#  - 4s - loss: 0.0020 - mse: 0.0040 - val_loss: 0.0015 - val_mse: 0.0029
# Epoch 122/300
#  - 4s - loss: 0.0020 - mse: 0.0039 - val_loss: 0.0014 - val_mse: 0.0028
# Epoch 123/300
#  - 4s - loss: 0.0020 - mse: 0.0039 - val_loss: 0.0014 - val_mse: 0.0029
# Epoch 124/300
#  - 4s - loss: 0.0020 - mse: 0.0039 - val_loss: 0.0014 - val_mse: 0.0028
# Epoch 125/300
#  - 4s - loss: 0.0020 - mse: 0.0039 - val_loss: 0.0016 - val_mse: 0.0032
# Epoch 126/300
#  - 4s - loss: 0.0020 - mse: 0.0040 - val_loss: 0.0015 - val_mse: 0.0031
# Epoch 127/300
#  - 4s - loss: 0.0020 - mse: 0.0039 - val_loss: 0.0018 - val_mse: 0.0036
# Epoch 128/300
#  - 4s - loss: 0.0020 - mse: 0.0039 - val_loss: 0.0014 - val_mse: 0.0027
# Epoch 129/300
#  - 4s - loss: 0.0020 - mse: 0.0039 - val_loss: 0.0013 - val_mse: 0.0027
# Epoch 130/300
#  - 4s - loss: 0.0020 - mse: 0.0039 - val_loss: 0.0015 - val_mse: 0.0031
# Epoch 131/300
#  - 4s - loss: 0.0020 - mse: 0.0040 - val_loss: 0.0017 - val_mse: 0.0034
# Epoch 132/300
#  - 4s - loss: 0.0020 - mse: 0.0039 - val_loss: 0.0014 - val_mse: 0.0027
# Epoch 133/300
#  - 4s - loss: 0.0019 - mse: 0.0039 - val_loss: 0.0015 - val_mse: 0.0029
# Epoch 134/300
#  - 4s - loss: 0.0020 - mse: 0.0039 - val_loss: 0.0016 - val_mse: 0.0033
# Epoch 135/300
#  - 4s - loss: 0.0020 - mse: 0.0039 - val_loss: 0.0014 - val_mse: 0.0029
# Epoch 136/300
#  - 4s - loss: 0.0020 - mse: 0.0039 - val_loss: 0.0015 - val_mse: 0.0030
# Epoch 137/300
#  - 4s - loss: 0.0020 - mse: 0.0039 - val_loss: 0.0014 - val_mse: 0.0029
# Epoch 138/300
#  - 4s - loss: 0.0019 - mse: 0.0039 - val_loss: 0.0014 - val_mse: 0.0027
# Epoch 139/300
#  - 4s - loss: 0.0020 - mse: 0.0040 - val_loss: 0.0014 - val_mse: 0.0028
# Epoch 140/300
#  - 4s - loss: 0.0020 - mse: 0.0039 - val_loss: 0.0017 - val_mse: 0.0034
# Epoch 141/300
#  - 4s - loss: 0.0020 - mse: 0.0040 - val_loss: 0.0016 - val_mse: 0.0031
# Epoch 142/300
#  - 4s - loss: 0.0019 - mse: 0.0039 - val_loss: 0.0015 - val_mse: 0.0029
# Epoch 143/300
#  - 4s - loss: 0.0020 - mse: 0.0039 - val_loss: 0.0013 - val_mse: 0.0027
# Epoch 144/300
#  - 4s - loss: 0.0019 - mse: 0.0039 - val_loss: 0.0014 - val_mse: 0.0028
# Epoch 145/300
#  - 4s - loss: 0.0020 - mse: 0.0040 - val_loss: 0.0014 - val_mse: 0.0027
# Epoch 146/300
#  - 4s - loss: 0.0019 - mse: 0.0039 - val_loss: 0.0014 - val_mse: 0.0028
# Epoch 147/300
#  - 4s - loss: 0.0019 - mse: 0.0039 - val_loss: 0.0014 - val_mse: 0.0027
# Epoch 148/300
#  - 3s - loss: 0.0020 - mse: 0.0039 - val_loss: 0.0014 - val_mse: 0.0028
# Epoch 149/300
#  - 4s - loss: 0.0020 - mse: 0.0039 - val_loss: 0.0015 - val_mse: 0.0030
# Epoch 150/300
#  - 4s - loss: 0.0019 - mse: 0.0039 - val_loss: 0.0015 - val_mse: 0.0030
# Epoch 151/300
#  - 4s - loss: 0.0019 - mse: 0.0039 - val_loss: 0.0014 - val_mse: 0.0027
# Epoch 152/300
#  - 4s - loss: 0.0020 - mse: 0.0039 - val_loss: 0.0014 - val_mse: 0.0028
# Epoch 153/300
#  - 4s - loss: 0.0020 - mse: 0.0039 - val_loss: 0.0015 - val_mse: 0.0029
# Epoch 154/300
#  - 4s - loss: 0.0020 - mse: 0.0039 - val_loss: 0.0014 - val_mse: 0.0028
# Epoch 155/300
#  - 4s - loss: 0.0019 - mse: 0.0039 - val_loss: 0.0015 - val_mse: 0.0029
# Epoch 156/300
#  - 4s - loss: 0.0019 - mse: 0.0039 - val_loss: 0.0013 - val_mse: 0.0027
# Epoch 157/300
#  - 4s - loss: 0.0020 - mse: 0.0039 - val_loss: 0.0015 - val_mse: 0.0031
# Epoch 158/300
#  - 4s - loss: 0.0019 - mse: 0.0039 - val_loss: 0.0014 - val_mse: 0.0029
# Epoch 159/300
#  - 4s - loss: 0.0020 - mse: 0.0040 - val_loss: 0.0015 - val_mse: 0.0029
# Epoch 160/300
#  - 4s - loss: 0.0019 - mse: 0.0039 - val_loss: 0.0017 - val_mse: 0.0034
# Epoch 161/300
#  - 4s - loss: 0.0019 - mse: 0.0039 - val_loss: 0.0015 - val_mse: 0.0029
# Epoch 162/300
#  - 4s - loss: 0.0020 - mse: 0.0039 - val_loss: 0.0013 - val_mse: 0.0027
# Epoch 163/300
#  - 4s - loss: 0.0019 - mse: 0.0039 - val_loss: 0.0014 - val_mse: 0.0028
# Epoch 164/300
#  - 4s - loss: 0.0020 - mse: 0.0039 - val_loss: 0.0015 - val_mse: 0.0029
# Epoch 165/300
#  - 4s - loss: 0.0020 - mse: 0.0039 - val_loss: 0.0013 - val_mse: 0.0026
# Epoch 166/300
#  - 4s - loss: 0.0020 - mse: 0.0039 - val_loss: 0.0014 - val_mse: 0.0029
# Epoch 167/300
#  - 4s - loss: 0.0019 - mse: 0.0039 - val_loss: 0.0014 - val_mse: 0.0029
# Epoch 168/300
#  - 4s - loss: 0.0019 - mse: 0.0039 - val_loss: 0.0015 - val_mse: 0.0031
# Epoch 169/300
#  - 4s - loss: 0.0020 - mse: 0.0039 - val_loss: 0.0014 - val_mse: 0.0027
# Epoch 170/300
#  - 4s - loss: 0.0020 - mse: 0.0039 - val_loss: 0.0014 - val_mse: 0.0028
# Epoch 171/300
#  - 4s - loss: 0.0019 - mse: 0.0039 - val_loss: 0.0014 - val_mse: 0.0029
# Epoch 172/300
#  - 4s - loss: 0.0020 - mse: 0.0039 - val_loss: 0.0013 - val_mse: 0.0026
# Epoch 173/300
#  - 4s - loss: 0.0020 - mse: 0.0039 - val_loss: 0.0015 - val_mse: 0.0029
# Epoch 174/300
#  - 4s - loss: 0.0020 - mse: 0.0039 - val_loss: 0.0013 - val_mse: 0.0027
# Epoch 175/300
#  - 4s - loss: 0.0019 - mse: 0.0038 - val_loss: 0.0014 - val_mse: 0.0027
# Epoch 176/300
#  - 4s - loss: 0.0019 - mse: 0.0039 - val_loss: 0.0014 - val_mse: 0.0027
# Epoch 177/300
#  - 4s - loss: 0.0019 - mse: 0.0039 - val_loss: 0.0015 - val_mse: 0.0030
# Epoch 178/300
#  - 4s - loss: 0.0020 - mse: 0.0039 - val_loss: 0.0015 - val_mse: 0.0029
# Epoch 179/300
#  - 4s - loss: 0.0019 - mse: 0.0039 - val_loss: 0.0015 - val_mse: 0.0030
# Epoch 180/300
#  - 4s - loss: 0.0019 - mse: 0.0039 - val_loss: 0.0015 - val_mse: 0.0030
# Epoch 181/300
#  - 4s - loss: 0.0019 - mse: 0.0038 - val_loss: 0.0013 - val_mse: 0.0026
# Epoch 182/300
#  - 4s - loss: 0.0020 - mse: 0.0039 - val_loss: 0.0014 - val_mse: 0.0028
# Epoch 183/300
#  - 4s - loss: 0.0020 - mse: 0.0039 - val_loss: 0.0014 - val_mse: 0.0028
# Epoch 184/300
#  - 4s - loss: 0.0019 - mse: 0.0038 - val_loss: 0.0014 - val_mse: 0.0028
# Epoch 185/300
#  - 4s - loss: 0.0019 - mse: 0.0039 - val_loss: 0.0014 - val_mse: 0.0027
# Epoch 186/300
#  - 4s - loss: 0.0020 - mse: 0.0039 - val_loss: 0.0015 - val_mse: 0.0030
# Epoch 187/300
#  - 4s - loss: 0.0019 - mse: 0.0039 - val_loss: 0.0014 - val_mse: 0.0028
# Epoch 188/300
#  - 4s - loss: 0.0020 - mse: 0.0039 - val_loss: 0.0016 - val_mse: 0.0031
# Epoch 189/300
#  - 4s - loss: 0.0019 - mse: 0.0039 - val_loss: 0.0016 - val_mse: 0.0032
# Epoch 190/300
#  - 4s - loss: 0.0019 - mse: 0.0039 - val_loss: 0.0014 - val_mse: 0.0027
# Epoch 191/300
#  - 4s - loss: 0.0019 - mse: 0.0039 - val_loss: 0.0016 - val_mse: 0.0032
# Epoch 192/300
#  - 4s - loss: 0.0019 - mse: 0.0039 - val_loss: 0.0015 - val_mse: 0.0030
# Epoch 193/300
#  - 4s - loss: 0.0019 - mse: 0.0039 - val_loss: 0.0014 - val_mse: 0.0028
# Epoch 194/300
#  - 4s - loss: 0.0020 - mse: 0.0039 - val_loss: 0.0015 - val_mse: 0.0031
# Epoch 195/300
#  - 4s - loss: 0.0020 - mse: 0.0039 - val_loss: 0.0015 - val_mse: 0.0029
# Epoch 196/300
#  - 4s - loss: 0.0019 - mse: 0.0039 - val_loss: 0.0014 - val_mse: 0.0027
# Epoch 197/300
#  - 4s - loss: 0.0020 - mse: 0.0039 - val_loss: 0.0014 - val_mse: 0.0027
# Epoch 198/300
#  - 4s - loss: 0.0019 - mse: 0.0038 - val_loss: 0.0015 - val_mse: 0.0029
# Epoch 199/300
#  - 4s - loss: 0.0020 - mse: 0.0039 - val_loss: 0.0014 - val_mse: 0.0027
# Epoch 200/300
#  - 4s - loss: 0.0019 - mse: 0.0039 - val_loss: 0.0014 - val_mse: 0.0027
# Epoch 201/300
#  - 4s - loss: 0.0019 - mse: 0.0039 - val_loss: 0.0015 - val_mse: 0.0030
# Epoch 202/300
#  - 4s - loss: 0.0019 - mse: 0.0039 - val_loss: 0.0014 - val_mse: 0.0029
# Epoch 203/300
#  - 4s - loss: 0.0019 - mse: 0.0038 - val_loss: 0.0014 - val_mse: 0.0027
# Epoch 204/300
#  - 4s - loss: 0.0019 - mse: 0.0039 - val_loss: 0.0016 - val_mse: 0.0032
# Epoch 205/300
#  - 4s - loss: 0.0019 - mse: 0.0039 - val_loss: 0.0016 - val_mse: 0.0032
# Epoch 206/300
#  - 4s - loss: 0.0019 - mse: 0.0038 - val_loss: 0.0016 - val_mse: 0.0032
# Epoch 207/300
#  - 4s - loss: 0.0019 - mse: 0.0039 - val_loss: 0.0015 - val_mse: 0.0030
# Epoch 208/300
#  - 4s - loss: 0.0019 - mse: 0.0039 - val_loss: 0.0015 - val_mse: 0.0030
# Epoch 209/300
#  - 4s - loss: 0.0019 - mse: 0.0038 - val_loss: 0.0014 - val_mse: 0.0029
# Epoch 210/300
#  - 4s - loss: 0.0019 - mse: 0.0038 - val_loss: 0.0015 - val_mse: 0.0030
# Epoch 211/300
#  - 4s - loss: 0.0019 - mse: 0.0039 - val_loss: 0.0014 - val_mse: 0.0029
# Epoch 212/300
#  - 4s - loss: 0.0019 - mse: 0.0039 - val_loss: 0.0015 - val_mse: 0.0030
# Epoch 213/300
#  - 4s - loss: 0.0019 - mse: 0.0039 - val_loss: 0.0014 - val_mse: 0.0028
# Epoch 214/300
#  - 4s - loss: 0.0019 - mse: 0.0039 - val_loss: 0.0013 - val_mse: 0.0027
# Epoch 215/300
#  - 4s - loss: 0.0019 - mse: 0.0039 - val_loss: 0.0014 - val_mse: 0.0028
# Epoch 216/300
#  - 4s - loss: 0.0019 - mse: 0.0039 - val_loss: 0.0013 - val_mse: 0.0027
# Epoch 217/300
#  - 4s - loss: 0.0019 - mse: 0.0039 - val_loss: 0.0016 - val_mse: 0.0032
# Epoch 218/300
#  - 4s - loss: 0.0020 - mse: 0.0039 - val_loss: 0.0014 - val_mse: 0.0028
# Epoch 219/300
#  - 4s - loss: 0.0019 - mse: 0.0039 - val_loss: 0.0015 - val_mse: 0.0029
# Epoch 220/300
#  - 4s - loss: 0.0020 - mse: 0.0039 - val_loss: 0.0015 - val_mse: 0.0030
# Epoch 221/300
#  - 4s - loss: 0.0020 - mse: 0.0039 - val_loss: 0.0014 - val_mse: 0.0028
# Epoch 222/300
#  - 4s - loss: 0.0019 - mse: 0.0039 - val_loss: 0.0013 - val_mse: 0.0027
# Epoch 223/300
#  - 4s - loss: 0.0019 - mse: 0.0038 - val_loss: 0.0014 - val_mse: 0.0028
# Epoch 224/300
#  - 4s - loss: 0.0019 - mse: 0.0038 - val_loss: 0.0015 - val_mse: 0.0029
# Epoch 225/300
#  - 4s - loss: 0.0019 - mse: 0.0038 - val_loss: 0.0015 - val_mse: 0.0031
# Epoch 226/300
#  - 4s - loss: 0.0019 - mse: 0.0039 - val_loss: 0.0016 - val_mse: 0.0031
# Epoch 227/300
#  - 4s - loss: 0.0019 - mse: 0.0038 - val_loss: 0.0015 - val_mse: 0.0030
# Epoch 228/300
#  - 4s - loss: 0.0019 - mse: 0.0038 - val_loss: 0.0013 - val_mse: 0.0027
# Epoch 229/300
#  - 4s - loss: 0.0019 - mse: 0.0039 - val_loss: 0.0014 - val_mse: 0.0028
# Epoch 230/300
#  - 4s - loss: 0.0019 - mse: 0.0038 - val_loss: 0.0017 - val_mse: 0.0034
# Epoch 231/300
#  - 4s - loss: 0.0020 - mse: 0.0039 - val_loss: 0.0015 - val_mse: 0.0031
# Epoch 232/300
#  - 4s - loss: 0.0019 - mse: 0.0039 - val_loss: 0.0016 - val_mse: 0.0031
# Epoch 233/300
#  - 4s - loss: 0.0019 - mse: 0.0038 - val_loss: 0.0015 - val_mse: 0.0029
# Epoch 234/300
#  - 4s - loss: 0.0019 - mse: 0.0038 - val_loss: 0.0014 - val_mse: 0.0029
# Epoch 235/300
#  - 4s - loss: 0.0019 - mse: 0.0039 - val_loss: 0.0014 - val_mse: 0.0027
# Epoch 236/300
#  - 4s - loss: 0.0019 - mse: 0.0038 - val_loss: 0.0015 - val_mse: 0.0030
# Epoch 237/300
#  - 4s - loss: 0.0019 - mse: 0.0038 - val_loss: 0.0014 - val_mse: 0.0029
# Epoch 238/300
#  - 4s - loss: 0.0019 - mse: 0.0038 - val_loss: 0.0017 - val_mse: 0.0035
# Epoch 239/300
#  - 4s - loss: 0.0019 - mse: 0.0038 - val_loss: 0.0015 - val_mse: 0.0029
# Epoch 240/300
#  - 4s - loss: 0.0019 - mse: 0.0038 - val_loss: 0.0014 - val_mse: 0.0029
# Epoch 241/300
#  - 4s - loss: 0.0019 - mse: 0.0038 - val_loss: 0.0015 - val_mse: 0.0030
# Epoch 242/300
#  - 4s - loss: 0.0019 - mse: 0.0039 - val_loss: 0.0015 - val_mse: 0.0030
# Epoch 243/300
#  - 4s - loss: 0.0019 - mse: 0.0039 - val_loss: 0.0014 - val_mse: 0.0027
# Epoch 244/300
#  - 4s - loss: 0.0019 - mse: 0.0038 - val_loss: 0.0016 - val_mse: 0.0031
# Epoch 245/300
#  - 4s - loss: 0.0019 - mse: 0.0038 - val_loss: 0.0016 - val_mse: 0.0031
# Epoch 246/300
#  - 4s - loss: 0.0019 - mse: 0.0038 - val_loss: 0.0014 - val_mse: 0.0028
# Epoch 247/300
#  - 4s - loss: 0.0019 - mse: 0.0039 - val_loss: 0.0014 - val_mse: 0.0029
# Epoch 248/300
#  - 4s - loss: 0.0019 - mse: 0.0038 - val_loss: 0.0014 - val_mse: 0.0028
# Epoch 249/300
#  - 4s - loss: 0.0019 - mse: 0.0038 - val_loss: 0.0015 - val_mse: 0.0031
# Epoch 250/300
#  - 4s - loss: 0.0019 - mse: 0.0038 - val_loss: 0.0014 - val_mse: 0.0027
# Epoch 251/300
#  - 4s - loss: 0.0019 - mse: 0.0039 - val_loss: 0.0016 - val_mse: 0.0031
# Epoch 252/300
#  - 4s - loss: 0.0019 - mse: 0.0038 - val_loss: 0.0013 - val_mse: 0.0027
# Epoch 253/300
#  - 4s - loss: 0.0019 - mse: 0.0038 - val_loss: 0.0013 - val_mse: 0.0026
# Epoch 254/300
#  - 4s - loss: 0.0019 - mse: 0.0038 - val_loss: 0.0013 - val_mse: 0.0026
# Epoch 255/300
#  - 4s - loss: 0.0019 - mse: 0.0038 - val_loss: 0.0015 - val_mse: 0.0030
# Epoch 256/300
#  - 4s - loss: 0.0019 - mse: 0.0038 - val_loss: 0.0014 - val_mse: 0.0028
# Epoch 257/300
#  - 4s - loss: 0.0019 - mse: 0.0039 - val_loss: 0.0013 - val_mse: 0.0027
# Epoch 258/300
#  - 4s - loss: 0.0019 - mse: 0.0038 - val_loss: 0.0013 - val_mse: 0.0026
# Epoch 259/300
#  - 4s - loss: 0.0019 - mse: 0.0039 - val_loss: 0.0014 - val_mse: 0.0028
# Epoch 260/300
#  - 4s - loss: 0.0019 - mse: 0.0038 - val_loss: 0.0017 - val_mse: 0.0033
# Epoch 261/300
#  - 4s - loss: 0.0019 - mse: 0.0039 - val_loss: 0.0015 - val_mse: 0.0030
# Epoch 262/300
#  - 4s - loss: 0.0019 - mse: 0.0038 - val_loss: 0.0014 - val_mse: 0.0029
# Epoch 263/300
#  - 4s - loss: 0.0019 - mse: 0.0038 - val_loss: 0.0016 - val_mse: 0.0032
# Epoch 264/300
#  - 4s - loss: 0.0019 - mse: 0.0038 - val_loss: 0.0016 - val_mse: 0.0032
# Epoch 265/300
#  - 4s - loss: 0.0019 - mse: 0.0038 - val_loss: 0.0014 - val_mse: 0.0028
# Epoch 266/300
#  - 4s - loss: 0.0019 - mse: 0.0039 - val_loss: 0.0013 - val_mse: 0.0027
# Epoch 267/300
#  - 4s - loss: 0.0020 - mse: 0.0039 - val_loss: 0.0014 - val_mse: 0.0029
# Epoch 268/300
#  - 4s - loss: 0.0019 - mse: 0.0038 - val_loss: 0.0013 - val_mse: 0.0027
# Epoch 269/300
#  - 4s - loss: 0.0019 - mse: 0.0039 - val_loss: 0.0016 - val_mse: 0.0031
# Epoch 270/300
#  - 4s - loss: 0.0019 - mse: 0.0038 - val_loss: 0.0016 - val_mse: 0.0031
# Epoch 271/300
#  - 4s - loss: 0.0019 - mse: 0.0038 - val_loss: 0.0015 - val_mse: 0.0029
# Epoch 272/300
#  - 4s - loss: 0.0019 - mse: 0.0038 - val_loss: 0.0016 - val_mse: 0.0032
# Epoch 273/300
#  - 4s - loss: 0.0019 - mse: 0.0038 - val_loss: 0.0014 - val_mse: 0.0029
# Epoch 274/300
#  - 4s - loss: 0.0019 - mse: 0.0038 - val_loss: 0.0014 - val_mse: 0.0028
# Epoch 275/300
#  - 4s - loss: 0.0019 - mse: 0.0038 - val_loss: 0.0014 - val_mse: 0.0029
# Epoch 276/300
#  - 4s - loss: 0.0019 - mse: 0.0038 - val_loss: 0.0018 - val_mse: 0.0035
# Epoch 277/300
#  - 4s - loss: 0.0019 - mse: 0.0038 - val_loss: 0.0015 - val_mse: 0.0030
# Epoch 278/300
#  - 4s - loss: 0.0019 - mse: 0.0038 - val_loss: 0.0014 - val_mse: 0.0028
# Epoch 279/300
#  - 4s - loss: 0.0019 - mse: 0.0038 - val_loss: 0.0018 - val_mse: 0.0036
# Epoch 280/300
#  - 4s - loss: 0.0019 - mse: 0.0038 - val_loss: 0.0015 - val_mse: 0.0030
# Epoch 281/300
#  - 4s - loss: 0.0019 - mse: 0.0038 - val_loss: 0.0014 - val_mse: 0.0028
# Epoch 282/300
#  - 4s - loss: 0.0019 - mse: 0.0038 - val_loss: 0.0014 - val_mse: 0.0028
# Epoch 283/300
#  - 4s - loss: 0.0019 - mse: 0.0038 - val_loss: 0.0013 - val_mse: 0.0027
# Epoch 284/300
#  - 4s - loss: 0.0019 - mse: 0.0038 - val_loss: 0.0015 - val_mse: 0.0030
# Epoch 285/300
#  - 4s - loss: 0.0019 - mse: 0.0038 - val_loss: 0.0015 - val_mse: 0.0029
# Epoch 286/300
#  - 4s - loss: 0.0019 - mse: 0.0038 - val_loss: 0.0015 - val_mse: 0.0030
# Epoch 287/300
#  - 4s - loss: 0.0019 - mse: 0.0038 - val_loss: 0.0014 - val_mse: 0.0028
# Epoch 288/300
#  - 4s - loss: 0.0019 - mse: 0.0038 - val_loss: 0.0014 - val_mse: 0.0028
# Epoch 289/300
#  - 4s - loss: 0.0019 - mse: 0.0038 - val_loss: 0.0016 - val_mse: 0.0032
# Epoch 290/300
#  - 4s - loss: 0.0019 - mse: 0.0038 - val_loss: 0.0016 - val_mse: 0.0032
# Epoch 291/300
#  - 4s - loss: 0.0019 - mse: 0.0038 - val_loss: 0.0016 - val_mse: 0.0032
# Epoch 292/300
#  - 4s - loss: 0.0019 - mse: 0.0038 - val_loss: 0.0016 - val_mse: 0.0031
# Epoch 293/300
#  - 4s - loss: 0.0019 - mse: 0.0038 - val_loss: 0.0014 - val_mse: 0.0028
# Epoch 294/300
#  - 4s - loss: 0.0019 - mse: 0.0038 - val_loss: 0.0015 - val_mse: 0.0029
# Epoch 295/300
#  - 4s - loss: 0.0019 - mse: 0.0038 - val_loss: 0.0015 - val_mse: 0.0029
# Epoch 296/300
#  - 4s - loss: 0.0019 - mse: 0.0039 - val_loss: 0.0017 - val_mse: 0.0034
# Epoch 297/300
#  - 4s - loss: 0.0019 - mse: 0.0039 - val_loss: 0.0015 - val_mse: 0.0029
# Epoch 298/300
#  - 4s - loss: 0.0019 - mse: 0.0038 - val_loss: 0.0016 - val_mse: 0.0033
# Epoch 299/300
#  - 4s - loss: 0.0019 - mse: 0.0038 - val_loss: 0.0014 - val_mse: 0.0029
# Epoch 300/300
#  - 4s - loss: 0.0019 - mse: 0.0038 - val_loss: 0.0014 - val_mse: 0.0028

# %%
#画图
plt.plot(history.history['loss'], label='train')
plt.plot(history.history['val_loss'], label='test')
plt.legend()
plt.show()

# %%
# make the prediction
yHat = model.predict(test_X)

inv_yHat = concatenate((yHat, test_x[:, 1:]), axis=1)   # 数组拼接
inv_yHat = inv_yHat[:, 0]

test_y = test_y.reshape((len(test_y), 1))
inv_y = concatenate((test_y, test_x[:, 1:]), axis=1)
inv_y = inv_y[:, 0]

rmse = sqrt(mean_squared_error(inv_yHat, inv_y))
print('Test RMSE: %.3f' % rmse)
mse = mean_squared_error(inv_yHat, inv_y)
print('Test MSE: %.3f' % mse)
# Out:
# Test RMSE: 0.053
# Test MSE: 0.003

# %%
yhat = model.predict(test_X)
test_X_reshaped = test_X.reshape((test_X.shape[0], test_X.shape[2]))

inv_yhat = concatenate((yhat, yhat, test_X_reshaped[:, 1:]), axis=1)
inv_yhat = inv_yhat[:, 0]
test_y = test_y.reshape((len(test_y), 1))
inv_y = concatenate((test_y, test_y, test_X_reshaped[:, 1:]), axis=1)
inv_y = inv_y[:, 0]
plt.plot(inv_yhat, label='prediction')
plt.plot(inv_y, label='real')
plt.xlabel('time')
plt.ylabel('cpu_usage_percent')
plt.legend()
plt.show()
plt.plot(inv_yhat[:100], label='prediction')
plt.plot(inv_y[:100], label='real_cpu_usage_percent')
plt.xlabel('time')
plt.ylabel('cpu_usage_percent')
plt.legend()
plt.show()
plt.plot(inv_yhat[:20], label='prediction')
plt.plot(inv_y[:20], label='real_cpu_usage_percent')
plt.xlabel('time')
plt.ylabel('cpu_usage_percent')
plt.legend()
plt.show()
