# %%
from math import sqrt
import tensorflow as tf
from tensorflow import keras
import pandas as pd
from tensorflow.keras import Sequential
from tensorflow.keras.layers import LSTM, Dense, Dropout, Conv1D, GRU
from tensorflow.keras.losses import mean_squared_error
from numpy.core._multiarray_umath import concatenate
from sklearn.preprocessing import MinMaxScaler
import matplotlib.pyplot as plt

from tensorflow.keras.layers import Layer
import tensorflow as tf
from keras import backend as K     
from keras.layers import Activation
from keras.utils.generic_utils import get_custom_objects

def swish(inputs):
    return (K.sigmoid(inputs) * inputs)
    
def h_swish(inputs):
    return inputs * tf.nn.relu6(inputs + 3) / 6
    
#函数绑定，将激活函数swish和h_swish添加到keras框的Activation类中
get_custom_objects().update({'swish': Activation(swish)})    
get_custom_objects().update({'h_swish': Activation(h_swish)})



# supervised监督学习函数


def series_to_supervised(data, columns, n_in=1, n_out=1, dropnan=True):
    n_vars = 1 if isinstance(data, list) else data.shape[1]
    df = pd.DataFrame(data)
    cols, names = list(), list()
    # input sequence (t-n, ... t-1)
    for i in range(n_in, 0, -1):
        cols.append(df.shift(i))
        names += [('%s%d(t-%d)' % (columns[j], j + 1, i))
                  for j in range(n_vars)]
    # forecast sequence (t, t+1, ... t+n)
    for i in range(0, n_out):
        cols.append(df.shift(-i))
        if i == 0:
            names += [('%s%d(t)' % (columns[j], j + 1)) for j in range(n_vars)]
        else:
            names += [('%s%d(t+%d)' % (columns[j], j + 1, i))
                      for j in range(n_vars)]
    # put it all together
    agg = pd.concat(cols, axis=1)
    agg.columns = names
    # drop rows with NaN values
    if dropnan:
        clean_agg = agg.dropna()
    return clean_agg

dataset = pd.read_csv(
    'task_usage_preprocessed.csv')

dataset_columns = dataset.columns
values = dataset.values
print(dataset)

# 归一化处理
scaler = MinMaxScaler(feature_range=(0, 1))
scaled = scaler.fit_transform(values)


# 监督学习
reframed = series_to_supervised(scaled, dataset_columns, 1, 1)
values = reframed.values

# 学习与检测数据的划分
n_train_hours = 400
train = values[:n_train_hours, :]
test = values[n_train_hours:, :]


# 监督学习结果划分
train_x, train_y = train[:, :-1], train[:, -1]
test_x, test_y = test[:, :-1], test[:, -1]

# 为了在LSTM中应用该数据，需要将其格式转化为3D format，即[Samples, timesteps, features]
train_X = train_x.reshape((train_x.shape[0], 1, train_x.shape[1]))
test_X = test_x.reshape((test_x.shape[0], 1, test_x.shape[1]))
# Out:
#      Time  mean_cpu_usage_rate  ...  maximum_cpu_usage  sampled_cpu_usage
# 0      10             0.176242  ...           0.730918           0.097729
# 1      15             0.138201  ...           0.552451           0.082357
# 2      20             0.139490  ...           0.553337           0.082896
# 3      25             0.160044  ...           0.601842           0.108727
# 4      30             0.154684  ...           0.571890           0.098590
# ..    ...                  ...  ...                ...                ...
# 583  2925             0.148851  ...           0.554342           0.092319
# 584  2930             0.191400  ...           0.660877           0.125024
# 585  2935             0.207017  ...           0.723978           0.133909
# 586  2940             0.206525  ...           0.739635           0.130044
# 587  2945             0.079510  ...           0.258525           0.055571
#
# [588 rows x 10 columns]

# %%
model = Sequential()
model.add(Conv1D(filters=32, kernel_size=5,
                 strides=1, padding="causal",
                 activation="relu"))
model.add(
    GRU(
        32,
        input_shape=(
            train_X.shape[1],
            train_X.shape[2]),
        return_sequences=True))
model.add(GRU(16, input_shape=(train_X.shape[1], train_X.shape[2])))
model.add(Dense(16, activation="swish"))
model.add(Dropout(0.2))
model.add(Dense(1))
model.compile(loss=tf.keras.losses.Huber(),
    optimizer='adam',
    metrics=["mse"])
history = model.fit(
    train_X,
    train_y,
    epochs=300,
    batch_size=72,
    validation_data=(
        test_X,
        test_y),
verbose = 2)
# Out:
# Epoch 1/300
# 6/6 - 0s - loss: 0.0884 - mse: 0.1768 - val_loss: 0.0375 - val_mse: 0.0751
# Epoch 2/300
# 6/6 - 0s - loss: 0.0652 - mse: 0.1304 - val_loss: 0.0240 - val_mse: 0.0479
# Epoch 3/300
# 6/6 - 0s - loss: 0.0450 - mse: 0.0900 - val_loss: 0.0133 - val_mse: 0.0265
# Epoch 4/300
# 6/6 - 0s - loss: 0.0276 - mse: 0.0551 - val_loss: 0.0079 - val_mse: 0.0157
# Epoch 5/300
# 6/6 - 0s - loss: 0.0170 - mse: 0.0340 - val_loss: 0.0134 - val_mse: 0.0267
# Epoch 6/300
# 6/6 - 0s - loss: 0.0164 - mse: 0.0327 - val_loss: 0.0195 - val_mse: 0.0390
# Epoch 7/300
# 6/6 - 0s - loss: 0.0173 - mse: 0.0346 - val_loss: 0.0146 - val_mse: 0.0291
# Epoch 8/300
# 6/6 - 0s - loss: 0.0151 - mse: 0.0301 - val_loss: 0.0108 - val_mse: 0.0215
# Epoch 9/300
# 6/6 - 0s - loss: 0.0150 - mse: 0.0299 - val_loss: 0.0099 - val_mse: 0.0198
# Epoch 10/300
# 6/6 - 0s - loss: 0.0139 - mse: 0.0277 - val_loss: 0.0113 - val_mse: 0.0225
# Epoch 11/300
# 6/6 - 0s - loss: 0.0133 - mse: 0.0266 - val_loss: 0.0134 - val_mse: 0.0269
# Epoch 12/300
# 6/6 - 0s - loss: 0.0138 - mse: 0.0276 - val_loss: 0.0149 - val_mse: 0.0298
# Epoch 13/300
# 6/6 - 0s - loss: 0.0116 - mse: 0.0232 - val_loss: 0.0143 - val_mse: 0.0286
# Epoch 14/300
# 6/6 - 0s - loss: 0.0120 - mse: 0.0239 - val_loss: 0.0142 - val_mse: 0.0283
# Epoch 15/300
# 6/6 - 0s - loss: 0.0120 - mse: 0.0241 - val_loss: 0.0159 - val_mse: 0.0318
# Epoch 16/300
# 6/6 - 0s - loss: 0.0122 - mse: 0.0245 - val_loss: 0.0166 - val_mse: 0.0332
# Epoch 17/300
# 6/6 - 0s - loss: 0.0117 - mse: 0.0233 - val_loss: 0.0180 - val_mse: 0.0360
# Epoch 18/300
# 6/6 - 0s - loss: 0.0099 - mse: 0.0199 - val_loss: 0.0187 - val_mse: 0.0375
# Epoch 19/300
# 6/6 - 0s - loss: 0.0092 - mse: 0.0184 - val_loss: 0.0219 - val_mse: 0.0439
# Epoch 20/300
# 6/6 - 0s - loss: 0.0086 - mse: 0.0172 - val_loss: 0.0206 - val_mse: 0.0412
# Epoch 21/300
# 6/6 - 0s - loss: 0.0090 - mse: 0.0181 - val_loss: 0.0241 - val_mse: 0.0482
# Epoch 22/300
# 6/6 - 0s - loss: 0.0088 - mse: 0.0177 - val_loss: 0.0263 - val_mse: 0.0526
# Epoch 23/300
# 6/6 - 0s - loss: 0.0079 - mse: 0.0157 - val_loss: 0.0212 - val_mse: 0.0424
# Epoch 24/300
# 6/6 - 0s - loss: 0.0076 - mse: 0.0151 - val_loss: 0.0260 - val_mse: 0.0519
# Epoch 25/300
# 6/6 - 0s - loss: 0.0074 - mse: 0.0148 - val_loss: 0.0217 - val_mse: 0.0434
# Epoch 26/300
# 6/6 - 0s - loss: 0.0060 - mse: 0.0120 - val_loss: 0.0229 - val_mse: 0.0457
# Epoch 27/300
# 6/6 - 0s - loss: 0.0063 - mse: 0.0126 - val_loss: 0.0204 - val_mse: 0.0408
# Epoch 28/300
# 6/6 - 0s - loss: 0.0058 - mse: 0.0116 - val_loss: 0.0201 - val_mse: 0.0401
# Epoch 29/300
# 6/6 - 0s - loss: 0.0054 - mse: 0.0109 - val_loss: 0.0145 - val_mse: 0.0289
# Epoch 30/300
# 6/6 - 0s - loss: 0.0053 - mse: 0.0106 - val_loss: 0.0160 - val_mse: 0.0321
# Epoch 31/300
# 6/6 - 0s - loss: 0.0052 - mse: 0.0104 - val_loss: 0.0096 - val_mse: 0.0193
# Epoch 32/300
# 6/6 - 0s - loss: 0.0045 - mse: 0.0090 - val_loss: 0.0104 - val_mse: 0.0209
# Epoch 33/300
# 6/6 - 0s - loss: 0.0051 - mse: 0.0101 - val_loss: 0.0091 - val_mse: 0.0182
# Epoch 34/300
# 6/6 - 0s - loss: 0.0044 - mse: 0.0088 - val_loss: 0.0082 - val_mse: 0.0164
# Epoch 35/300
# 6/6 - 0s - loss: 0.0043 - mse: 0.0086 - val_loss: 0.0083 - val_mse: 0.0166
# Epoch 36/300
# 6/6 - 0s - loss: 0.0042 - mse: 0.0085 - val_loss: 0.0081 - val_mse: 0.0161
# Epoch 37/300
# 6/6 - 0s - loss: 0.0044 - mse: 0.0088 - val_loss: 0.0063 - val_mse: 0.0126
# Epoch 38/300
# 6/6 - 0s - loss: 0.0042 - mse: 0.0084 - val_loss: 0.0061 - val_mse: 0.0122
# Epoch 39/300
# 6/6 - 0s - loss: 0.0037 - mse: 0.0074 - val_loss: 0.0061 - val_mse: 0.0123
# Epoch 40/300
# 6/6 - 0s - loss: 0.0039 - mse: 0.0079 - val_loss: 0.0050 - val_mse: 0.0099
# Epoch 41/300
# 6/6 - 0s - loss: 0.0039 - mse: 0.0078 - val_loss: 0.0040 - val_mse: 0.0081
# Epoch 42/300
# 6/6 - 0s - loss: 0.0043 - mse: 0.0086 - val_loss: 0.0055 - val_mse: 0.0110
# Epoch 43/300
# 6/6 - 0s - loss: 0.0037 - mse: 0.0075 - val_loss: 0.0040 - val_mse: 0.0080
# Epoch 44/300
# 6/6 - 0s - loss: 0.0034 - mse: 0.0067 - val_loss: 0.0045 - val_mse: 0.0091
# Epoch 45/300
# 6/6 - 0s - loss: 0.0037 - mse: 0.0074 - val_loss: 0.0057 - val_mse: 0.0114
# Epoch 46/300
# 6/6 - 0s - loss: 0.0042 - mse: 0.0084 - val_loss: 0.0046 - val_mse: 0.0093
# Epoch 47/300
# 6/6 - 0s - loss: 0.0037 - mse: 0.0074 - val_loss: 0.0034 - val_mse: 0.0068
# Epoch 48/300
# 6/6 - 0s - loss: 0.0035 - mse: 0.0071 - val_loss: 0.0052 - val_mse: 0.0105
# Epoch 49/300
# 6/6 - 0s - loss: 0.0038 - mse: 0.0075 - val_loss: 0.0044 - val_mse: 0.0088
# Epoch 50/300
# 6/6 - 0s - loss: 0.0036 - mse: 0.0072 - val_loss: 0.0046 - val_mse: 0.0092
# Epoch 51/300
# 6/6 - 0s - loss: 0.0039 - mse: 0.0077 - val_loss: 0.0047 - val_mse: 0.0094
# Epoch 52/300
# 6/6 - 0s - loss: 0.0035 - mse: 0.0070 - val_loss: 0.0042 - val_mse: 0.0083
# Epoch 53/300
# 6/6 - 0s - loss: 0.0031 - mse: 0.0062 - val_loss: 0.0046 - val_mse: 0.0092
# Epoch 54/300
# 6/6 - 0s - loss: 0.0035 - mse: 0.0070 - val_loss: 0.0027 - val_mse: 0.0054
# Epoch 55/300
# 6/6 - 0s - loss: 0.0036 - mse: 0.0073 - val_loss: 0.0044 - val_mse: 0.0089
# Epoch 56/300
# 6/6 - 0s - loss: 0.0035 - mse: 0.0069 - val_loss: 0.0040 - val_mse: 0.0080
# Epoch 57/300
# 6/6 - 0s - loss: 0.0036 - mse: 0.0072 - val_loss: 0.0042 - val_mse: 0.0084
# Epoch 58/300
# 6/6 - 0s - loss: 0.0039 - mse: 0.0078 - val_loss: 0.0025 - val_mse: 0.0051
# Epoch 59/300
# 6/6 - 0s - loss: 0.0034 - mse: 0.0068 - val_loss: 0.0032 - val_mse: 0.0065
# Epoch 60/300
# 6/6 - 0s - loss: 0.0038 - mse: 0.0075 - val_loss: 0.0047 - val_mse: 0.0094
# Epoch 61/300
# 6/6 - 0s - loss: 0.0037 - mse: 0.0075 - val_loss: 0.0026 - val_mse: 0.0051
# Epoch 62/300
# 6/6 - 0s - loss: 0.0034 - mse: 0.0067 - val_loss: 0.0044 - val_mse: 0.0089
# Epoch 63/300
# 6/6 - 0s - loss: 0.0035 - mse: 0.0070 - val_loss: 0.0035 - val_mse: 0.0070
# Epoch 64/300
# 6/6 - 0s - loss: 0.0033 - mse: 0.0067 - val_loss: 0.0023 - val_mse: 0.0045
# Epoch 65/300
# 6/6 - 0s - loss: 0.0029 - mse: 0.0059 - val_loss: 0.0042 - val_mse: 0.0083
# Epoch 66/300
# 6/6 - 0s - loss: 0.0035 - mse: 0.0069 - val_loss: 0.0024 - val_mse: 0.0048
# Epoch 67/300
# 6/6 - 0s - loss: 0.0032 - mse: 0.0065 - val_loss: 0.0037 - val_mse: 0.0074
# Epoch 68/300
# 6/6 - 0s - loss: 0.0031 - mse: 0.0062 - val_loss: 0.0027 - val_mse: 0.0055
# Epoch 69/300
# 6/6 - 0s - loss: 0.0030 - mse: 0.0059 - val_loss: 0.0027 - val_mse: 0.0054
# Epoch 70/300
# 6/6 - 0s - loss: 0.0036 - mse: 0.0072 - val_loss: 0.0024 - val_mse: 0.0047
# Epoch 71/300
# 6/6 - 0s - loss: 0.0036 - mse: 0.0072 - val_loss: 0.0036 - val_mse: 0.0071
# Epoch 72/300
# 6/6 - 0s - loss: 0.0034 - mse: 0.0069 - val_loss: 0.0031 - val_mse: 0.0063
# Epoch 73/300
# 6/6 - 0s - loss: 0.0034 - mse: 0.0068 - val_loss: 0.0022 - val_mse: 0.0044
# Epoch 74/300
# 6/6 - 0s - loss: 0.0034 - mse: 0.0069 - val_loss: 0.0031 - val_mse: 0.0061
# Epoch 75/300
# 6/6 - 0s - loss: 0.0033 - mse: 0.0065 - val_loss: 0.0029 - val_mse: 0.0058
# Epoch 76/300
# 6/6 - 0s - loss: 0.0030 - mse: 0.0061 - val_loss: 0.0028 - val_mse: 0.0056
# Epoch 77/300
# 6/6 - 0s - loss: 0.0030 - mse: 0.0061 - val_loss: 0.0024 - val_mse: 0.0048
# Epoch 78/300
# 6/6 - 0s - loss: 0.0031 - mse: 0.0062 - val_loss: 0.0027 - val_mse: 0.0054
# Epoch 79/300
# 6/6 - 0s - loss: 0.0033 - mse: 0.0065 - val_loss: 0.0023 - val_mse: 0.0046
# Epoch 80/300
# 6/6 - 0s - loss: 0.0027 - mse: 0.0055 - val_loss: 0.0028 - val_mse: 0.0056
# Epoch 81/300
# 6/6 - 0s - loss: 0.0032 - mse: 0.0065 - val_loss: 0.0023 - val_mse: 0.0045
# Epoch 82/300
# 6/6 - 0s - loss: 0.0028 - mse: 0.0056 - val_loss: 0.0027 - val_mse: 0.0055
# Epoch 83/300
# 6/6 - 0s - loss: 0.0034 - mse: 0.0067 - val_loss: 0.0027 - val_mse: 0.0055
# Epoch 84/300
# 6/6 - 0s - loss: 0.0028 - mse: 0.0057 - val_loss: 0.0023 - val_mse: 0.0046
# Epoch 85/300
# 6/6 - 0s - loss: 0.0031 - mse: 0.0062 - val_loss: 0.0030 - val_mse: 0.0060
# Epoch 86/300
# 6/6 - 0s - loss: 0.0027 - mse: 0.0054 - val_loss: 0.0023 - val_mse: 0.0045
# Epoch 87/300
# 6/6 - 0s - loss: 0.0028 - mse: 0.0056 - val_loss: 0.0038 - val_mse: 0.0076
# Epoch 88/300
# 6/6 - 0s - loss: 0.0028 - mse: 0.0057 - val_loss: 0.0024 - val_mse: 0.0048
# Epoch 89/300
# 6/6 - 0s - loss: 0.0031 - mse: 0.0063 - val_loss: 0.0026 - val_mse: 0.0053
# Epoch 90/300
# 6/6 - 0s - loss: 0.0028 - mse: 0.0055 - val_loss: 0.0026 - val_mse: 0.0053
# Epoch 91/300
# 6/6 - 0s - loss: 0.0028 - mse: 0.0056 - val_loss: 0.0029 - val_mse: 0.0059
# Epoch 92/300
# 6/6 - 0s - loss: 0.0027 - mse: 0.0055 - val_loss: 0.0018 - val_mse: 0.0036
# Epoch 93/300
# 6/6 - 0s - loss: 0.0032 - mse: 0.0064 - val_loss: 0.0025 - val_mse: 0.0049
# Epoch 94/300
# 6/6 - 0s - loss: 0.0030 - mse: 0.0059 - val_loss: 0.0024 - val_mse: 0.0049
# Epoch 95/300
# 6/6 - 0s - loss: 0.0028 - mse: 0.0056 - val_loss: 0.0026 - val_mse: 0.0051
# Epoch 96/300
# 6/6 - 0s - loss: 0.0028 - mse: 0.0057 - val_loss: 0.0017 - val_mse: 0.0034
# Epoch 97/300
# 6/6 - 0s - loss: 0.0030 - mse: 0.0059 - val_loss: 0.0042 - val_mse: 0.0084
# Epoch 98/300
# 6/6 - 0s - loss: 0.0029 - mse: 0.0058 - val_loss: 0.0018 - val_mse: 0.0036
# Epoch 99/300
# 6/6 - 0s - loss: 0.0027 - mse: 0.0054 - val_loss: 0.0020 - val_mse: 0.0039
# Epoch 100/300
# 6/6 - 0s - loss: 0.0029 - mse: 0.0058 - val_loss: 0.0025 - val_mse: 0.0050
# Epoch 101/300
# 6/6 - 0s - loss: 0.0027 - mse: 0.0053 - val_loss: 0.0017 - val_mse: 0.0033
# Epoch 102/300
# 6/6 - 0s - loss: 0.0030 - mse: 0.0061 - val_loss: 0.0044 - val_mse: 0.0089
# Epoch 103/300
# 6/6 - 0s - loss: 0.0032 - mse: 0.0064 - val_loss: 0.0021 - val_mse: 0.0041
# Epoch 104/300
# 6/6 - 0s - loss: 0.0030 - mse: 0.0060 - val_loss: 0.0016 - val_mse: 0.0033
# Epoch 105/300
# 6/6 - 0s - loss: 0.0032 - mse: 0.0064 - val_loss: 0.0031 - val_mse: 0.0062
# Epoch 106/300
# 6/6 - 0s - loss: 0.0028 - mse: 0.0057 - val_loss: 0.0027 - val_mse: 0.0054
# Epoch 107/300
# 6/6 - 0s - loss: 0.0030 - mse: 0.0060 - val_loss: 0.0019 - val_mse: 0.0039
# Epoch 108/300
# 6/6 - 0s - loss: 0.0030 - mse: 0.0059 - val_loss: 0.0032 - val_mse: 0.0064
# Epoch 109/300
# 6/6 - 0s - loss: 0.0031 - mse: 0.0061 - val_loss: 0.0023 - val_mse: 0.0046
# Epoch 110/300
# 6/6 - 0s - loss: 0.0028 - mse: 0.0056 - val_loss: 0.0026 - val_mse: 0.0051
# Epoch 111/300
# 6/6 - 0s - loss: 0.0028 - mse: 0.0055 - val_loss: 0.0017 - val_mse: 0.0033
# Epoch 112/300
# 6/6 - 0s - loss: 0.0028 - mse: 0.0056 - val_loss: 0.0025 - val_mse: 0.0050
# Epoch 113/300
# 6/6 - 0s - loss: 0.0029 - mse: 0.0059 - val_loss: 0.0022 - val_mse: 0.0045
# Epoch 114/300
# 6/6 - 0s - loss: 0.0027 - mse: 0.0054 - val_loss: 0.0015 - val_mse: 0.0031
# Epoch 115/300
# 6/6 - 0s - loss: 0.0029 - mse: 0.0058 - val_loss: 0.0029 - val_mse: 0.0059
# Epoch 116/300
# 6/6 - 0s - loss: 0.0025 - mse: 0.0049 - val_loss: 0.0019 - val_mse: 0.0039
# Epoch 117/300
# 6/6 - 0s - loss: 0.0027 - mse: 0.0053 - val_loss: 0.0016 - val_mse: 0.0032
# Epoch 118/300
# 6/6 - 0s - loss: 0.0030 - mse: 0.0059 - val_loss: 0.0041 - val_mse: 0.0083
# Epoch 119/300
# 6/6 - 0s - loss: 0.0036 - mse: 0.0071 - val_loss: 0.0017 - val_mse: 0.0034
# Epoch 120/300
# 6/6 - 0s - loss: 0.0031 - mse: 0.0062 - val_loss: 0.0016 - val_mse: 0.0033
# Epoch 121/300
# 6/6 - 0s - loss: 0.0032 - mse: 0.0064 - val_loss: 0.0043 - val_mse: 0.0086
# Epoch 122/300
# 6/6 - 0s - loss: 0.0029 - mse: 0.0057 - val_loss: 0.0018 - val_mse: 0.0036
# Epoch 123/300
# 6/6 - 0s - loss: 0.0026 - mse: 0.0052 - val_loss: 0.0025 - val_mse: 0.0050
# Epoch 124/300
# 6/6 - 0s - loss: 0.0026 - mse: 0.0051 - val_loss: 0.0033 - val_mse: 0.0067
# Epoch 125/300
# 6/6 - 0s - loss: 0.0024 - mse: 0.0049 - val_loss: 0.0019 - val_mse: 0.0037
# Epoch 126/300
# 6/6 - 0s - loss: 0.0028 - mse: 0.0055 - val_loss: 0.0018 - val_mse: 0.0036
# Epoch 127/300
# 6/6 - 0s - loss: 0.0028 - mse: 0.0055 - val_loss: 0.0029 - val_mse: 0.0059
# Epoch 128/300
# 6/6 - 0s - loss: 0.0029 - mse: 0.0058 - val_loss: 0.0015 - val_mse: 0.0031
# Epoch 129/300
# 6/6 - 0s - loss: 0.0026 - mse: 0.0053 - val_loss: 0.0024 - val_mse: 0.0048
# Epoch 130/300
# 6/6 - 0s - loss: 0.0026 - mse: 0.0051 - val_loss: 0.0022 - val_mse: 0.0044
# Epoch 131/300
# 6/6 - 0s - loss: 0.0024 - mse: 0.0048 - val_loss: 0.0019 - val_mse: 0.0038
# Epoch 132/300
# 6/6 - 0s - loss: 0.0023 - mse: 0.0045 - val_loss: 0.0018 - val_mse: 0.0035
# Epoch 133/300
# 6/6 - 0s - loss: 0.0021 - mse: 0.0043 - val_loss: 0.0018 - val_mse: 0.0037
# Epoch 134/300
# 6/6 - 0s - loss: 0.0025 - mse: 0.0051 - val_loss: 0.0022 - val_mse: 0.0044
# Epoch 135/300
# 6/6 - 0s - loss: 0.0028 - mse: 0.0055 - val_loss: 0.0015 - val_mse: 0.0030
# Epoch 136/300
# 6/6 - 0s - loss: 0.0023 - mse: 0.0047 - val_loss: 0.0024 - val_mse: 0.0047
# Epoch 137/300
# 6/6 - 0s - loss: 0.0023 - mse: 0.0046 - val_loss: 0.0016 - val_mse: 0.0031
# Epoch 138/300
# 6/6 - 0s - loss: 0.0022 - mse: 0.0044 - val_loss: 0.0024 - val_mse: 0.0048
# Epoch 139/300
# 6/6 - 0s - loss: 0.0022 - mse: 0.0044 - val_loss: 0.0018 - val_mse: 0.0035
# Epoch 140/300
# 6/6 - 0s - loss: 0.0026 - mse: 0.0053 - val_loss: 0.0014 - val_mse: 0.0028
# Epoch 141/300
# 6/6 - 0s - loss: 0.0026 - mse: 0.0051 - val_loss: 0.0026 - val_mse: 0.0052
# Epoch 142/300
# 6/6 - 0s - loss: 0.0024 - mse: 0.0048 - val_loss: 0.0017 - val_mse: 0.0033
# Epoch 143/300
# 6/6 - 0s - loss: 0.0026 - mse: 0.0052 - val_loss: 0.0017 - val_mse: 0.0035
# Epoch 144/300
# 6/6 - 0s - loss: 0.0023 - mse: 0.0047 - val_loss: 0.0020 - val_mse: 0.0039
# Epoch 145/300
# 6/6 - 0s - loss: 0.0025 - mse: 0.0049 - val_loss: 0.0018 - val_mse: 0.0035
# Epoch 146/300
# 6/6 - 0s - loss: 0.0026 - mse: 0.0053 - val_loss: 0.0020 - val_mse: 0.0040
# Epoch 147/300
# 6/6 - 0s - loss: 0.0021 - mse: 0.0042 - val_loss: 0.0013 - val_mse: 0.0027
# Epoch 148/300
# 6/6 - 0s - loss: 0.0025 - mse: 0.0049 - val_loss: 0.0014 - val_mse: 0.0029
# Epoch 149/300
# 6/6 - 0s - loss: 0.0026 - mse: 0.0053 - val_loss: 0.0022 - val_mse: 0.0043
# Epoch 150/300
# 6/6 - 0s - loss: 0.0024 - mse: 0.0047 - val_loss: 0.0013 - val_mse: 0.0027
# Epoch 151/300
# 6/6 - 0s - loss: 0.0025 - mse: 0.0050 - val_loss: 0.0021 - val_mse: 0.0043
# Epoch 152/300
# 6/6 - 0s - loss: 0.0024 - mse: 0.0048 - val_loss: 0.0020 - val_mse: 0.0040
# Epoch 153/300
# 6/6 - 0s - loss: 0.0027 - mse: 0.0054 - val_loss: 0.0013 - val_mse: 0.0026
# Epoch 154/300
# 6/6 - 0s - loss: 0.0023 - mse: 0.0046 - val_loss: 0.0018 - val_mse: 0.0036
# Epoch 155/300
# 6/6 - 0s - loss: 0.0023 - mse: 0.0047 - val_loss: 0.0018 - val_mse: 0.0037
# Epoch 156/300
# 6/6 - 0s - loss: 0.0022 - mse: 0.0043 - val_loss: 0.0016 - val_mse: 0.0031
# Epoch 157/300
# 6/6 - 0s - loss: 0.0023 - mse: 0.0046 - val_loss: 0.0012 - val_mse: 0.0025
# Epoch 158/300
# 6/6 - 0s - loss: 0.0024 - mse: 0.0048 - val_loss: 0.0016 - val_mse: 0.0032
# Epoch 159/300
# 6/6 - 0s - loss: 0.0023 - mse: 0.0046 - val_loss: 0.0015 - val_mse: 0.0031
# Epoch 160/300
# 6/6 - 0s - loss: 0.0025 - mse: 0.0050 - val_loss: 0.0013 - val_mse: 0.0026
# Epoch 161/300
# 6/6 - 0s - loss: 0.0025 - mse: 0.0049 - val_loss: 0.0014 - val_mse: 0.0028
# Epoch 162/300
# 6/6 - 0s - loss: 0.0023 - mse: 0.0045 - val_loss: 0.0012 - val_mse: 0.0025
# Epoch 163/300
# 6/6 - 0s - loss: 0.0020 - mse: 0.0041 - val_loss: 0.0014 - val_mse: 0.0029
# Epoch 164/300
# 6/6 - 0s - loss: 0.0023 - mse: 0.0046 - val_loss: 0.0019 - val_mse: 0.0038
# Epoch 165/300
# 6/6 - 0s - loss: 0.0025 - mse: 0.0050 - val_loss: 0.0012 - val_mse: 0.0023
# Epoch 166/300
# 6/6 - 0s - loss: 0.0026 - mse: 0.0051 - val_loss: 0.0015 - val_mse: 0.0030
# Epoch 167/300
# 6/6 - 0s - loss: 0.0021 - mse: 0.0043 - val_loss: 0.0014 - val_mse: 0.0028
# Epoch 168/300
# 6/6 - 0s - loss: 0.0020 - mse: 0.0040 - val_loss: 0.0022 - val_mse: 0.0043
# Epoch 169/300
# 6/6 - 0s - loss: 0.0023 - mse: 0.0046 - val_loss: 0.0013 - val_mse: 0.0025
# Epoch 170/300
# 6/6 - 0s - loss: 0.0024 - mse: 0.0048 - val_loss: 0.0011 - val_mse: 0.0023
# Epoch 171/300
# 6/6 - 0s - loss: 0.0021 - mse: 0.0042 - val_loss: 0.0017 - val_mse: 0.0034
# Epoch 172/300
# 6/6 - 0s - loss: 0.0023 - mse: 0.0046 - val_loss: 0.0024 - val_mse: 0.0048
# Epoch 173/300
# 6/6 - 0s - loss: 0.0021 - mse: 0.0043 - val_loss: 0.0012 - val_mse: 0.0024
# Epoch 174/300
# 6/6 - 0s - loss: 0.0022 - mse: 0.0045 - val_loss: 0.0012 - val_mse: 0.0023
# Epoch 175/300
# 6/6 - 0s - loss: 0.0019 - mse: 0.0039 - val_loss: 0.0021 - val_mse: 0.0041
# Epoch 176/300
# 6/6 - 0s - loss: 0.0019 - mse: 0.0037 - val_loss: 0.0013 - val_mse: 0.0026
# Epoch 177/300
# 6/6 - 0s - loss: 0.0020 - mse: 0.0040 - val_loss: 0.0019 - val_mse: 0.0037
# Epoch 178/300
# 6/6 - 0s - loss: 0.0023 - mse: 0.0046 - val_loss: 0.0012 - val_mse: 0.0024
# Epoch 179/300
# 6/6 - 0s - loss: 0.0021 - mse: 0.0043 - val_loss: 0.0015 - val_mse: 0.0030
# Epoch 180/300
# 6/6 - 0s - loss: 0.0022 - mse: 0.0043 - val_loss: 0.0018 - val_mse: 0.0037
# Epoch 181/300
# 6/6 - 0s - loss: 0.0018 - mse: 0.0036 - val_loss: 0.0015 - val_mse: 0.0031
# Epoch 182/300
# 6/6 - 0s - loss: 0.0021 - mse: 0.0041 - val_loss: 0.0012 - val_mse: 0.0025
# Epoch 183/300
# 6/6 - 0s - loss: 0.0020 - mse: 0.0041 - val_loss: 0.0014 - val_mse: 0.0028
# Epoch 184/300
# 6/6 - 0s - loss: 0.0017 - mse: 0.0034 - val_loss: 0.0014 - val_mse: 0.0027
# Epoch 185/300
# 6/6 - 0s - loss: 0.0019 - mse: 0.0037 - val_loss: 0.0021 - val_mse: 0.0043
# Epoch 186/300
# 6/6 - 0s - loss: 0.0020 - mse: 0.0040 - val_loss: 0.0011 - val_mse: 0.0021
# Epoch 187/300
# 6/6 - 0s - loss: 0.0020 - mse: 0.0039 - val_loss: 0.0012 - val_mse: 0.0024
# Epoch 188/300
# 6/6 - 0s - loss: 0.0019 - mse: 0.0038 - val_loss: 0.0010 - val_mse: 0.0021
# Epoch 189/300
# 6/6 - 0s - loss: 0.0021 - mse: 0.0043 - val_loss: 0.0013 - val_mse: 0.0025
# Epoch 190/300
# 6/6 - 0s - loss: 0.0017 - mse: 0.0034 - val_loss: 0.0013 - val_mse: 0.0026
# Epoch 191/300
# 6/6 - 0s - loss: 0.0021 - mse: 0.0042 - val_loss: 0.0014 - val_mse: 0.0027
# Epoch 192/300
# 6/6 - 0s - loss: 0.0021 - mse: 0.0041 - val_loss: 9.2831e-04 - val_mse: 0.0019
# Epoch 193/300
# 6/6 - 0s - loss: 0.0020 - mse: 0.0041 - val_loss: 0.0012 - val_mse: 0.0024
# Epoch 194/300
# 6/6 - 0s - loss: 0.0018 - mse: 0.0036 - val_loss: 0.0012 - val_mse: 0.0024
# Epoch 195/300
# 6/6 - 0s - loss: 0.0017 - mse: 0.0034 - val_loss: 0.0013 - val_mse: 0.0025
# Epoch 196/300
# 6/6 - 0s - loss: 0.0018 - mse: 0.0037 - val_loss: 9.0952e-04 - val_mse: 0.0018
# Epoch 197/300
# 6/6 - 0s - loss: 0.0016 - mse: 0.0033 - val_loss: 8.8102e-04 - val_mse: 0.0018
# Epoch 198/300
# 6/6 - 0s - loss: 0.0019 - mse: 0.0037 - val_loss: 9.1137e-04 - val_mse: 0.0018
# Epoch 199/300
# 6/6 - 0s - loss: 0.0019 - mse: 0.0038 - val_loss: 8.8453e-04 - val_mse: 0.0018
# Epoch 200/300
# 6/6 - 0s - loss: 0.0016 - mse: 0.0032 - val_loss: 0.0015 - val_mse: 0.0030
# Epoch 201/300
# 6/6 - 0s - loss: 0.0017 - mse: 0.0035 - val_loss: 0.0013 - val_mse: 0.0026
# Epoch 202/300
# 6/6 - 0s - loss: 0.0017 - mse: 0.0034 - val_loss: 9.1100e-04 - val_mse: 0.0018
# Epoch 203/300
# 6/6 - 0s - loss: 0.0017 - mse: 0.0035 - val_loss: 8.8071e-04 - val_mse: 0.0018
# Epoch 204/300
# 6/6 - 0s - loss: 0.0023 - mse: 0.0046 - val_loss: 9.5058e-04 - val_mse: 0.0019
# Epoch 205/300
# 6/6 - 0s - loss: 0.0018 - mse: 0.0036 - val_loss: 0.0015 - val_mse: 0.0030
# Epoch 206/300
# 6/6 - 0s - loss: 0.0017 - mse: 0.0033 - val_loss: 0.0018 - val_mse: 0.0036
# Epoch 207/300
# 6/6 - 0s - loss: 0.0015 - mse: 0.0030 - val_loss: 0.0022 - val_mse: 0.0045
# Epoch 208/300
# 6/6 - 0s - loss: 0.0020 - mse: 0.0040 - val_loss: 0.0012 - val_mse: 0.0025
# Epoch 209/300
# 6/6 - 0s - loss: 0.0020 - mse: 0.0041 - val_loss: 8.7138e-04 - val_mse: 0.0017
# Epoch 210/300
# 6/6 - 0s - loss: 0.0019 - mse: 0.0039 - val_loss: 9.3530e-04 - val_mse: 0.0019
# Epoch 211/300
# 6/6 - 0s - loss: 0.0019 - mse: 0.0038 - val_loss: 0.0020 - val_mse: 0.0040
# Epoch 212/300
# 6/6 - 0s - loss: 0.0017 - mse: 0.0034 - val_loss: 0.0016 - val_mse: 0.0032
# Epoch 213/300
# 6/6 - 0s - loss: 0.0016 - mse: 0.0032 - val_loss: 8.5213e-04 - val_mse: 0.0017
# Epoch 214/300
# 6/6 - 0s - loss: 0.0016 - mse: 0.0032 - val_loss: 0.0013 - val_mse: 0.0025
# Epoch 215/300
# 6/6 - 0s - loss: 0.0016 - mse: 0.0032 - val_loss: 0.0014 - val_mse: 0.0027
# Epoch 216/300
# 6/6 - 0s - loss: 0.0016 - mse: 0.0031 - val_loss: 9.1357e-04 - val_mse: 0.0018
# Epoch 217/300
# 6/6 - 0s - loss: 0.0017 - mse: 0.0035 - val_loss: 7.4763e-04 - val_mse: 0.0015
# Epoch 218/300
# 6/6 - 0s - loss: 0.0019 - mse: 0.0037 - val_loss: 7.3365e-04 - val_mse: 0.0015
# Epoch 219/300
# 6/6 - 0s - loss: 0.0016 - mse: 0.0031 - val_loss: 7.5401e-04 - val_mse: 0.0015
# Epoch 220/300
# 6/6 - 0s - loss: 0.0017 - mse: 0.0035 - val_loss: 7.1758e-04 - val_mse: 0.0014
# Epoch 221/300
# 6/6 - 0s - loss: 0.0016 - mse: 0.0031 - val_loss: 9.0591e-04 - val_mse: 0.0018
# Epoch 222/300
# 6/6 - 0s - loss: 0.0015 - mse: 0.0030 - val_loss: 7.1968e-04 - val_mse: 0.0014
# Epoch 223/300
# 6/6 - 0s - loss: 0.0015 - mse: 0.0029 - val_loss: 7.0340e-04 - val_mse: 0.0014
# Epoch 224/300
# 6/6 - 0s - loss: 0.0015 - mse: 0.0030 - val_loss: 0.0016 - val_mse: 0.0033
# Epoch 225/300
# 6/6 - 0s - loss: 0.0020 - mse: 0.0040 - val_loss: 0.0018 - val_mse: 0.0036
# Epoch 226/300
# 6/6 - 0s - loss: 0.0017 - mse: 0.0034 - val_loss: 0.0011 - val_mse: 0.0022
# Epoch 227/300
# 6/6 - 0s - loss: 0.0016 - mse: 0.0032 - val_loss: 7.8342e-04 - val_mse: 0.0016
# Epoch 228/300
# 6/6 - 0s - loss: 0.0017 - mse: 0.0035 - val_loss: 9.1017e-04 - val_mse: 0.0018
# Epoch 229/300
# 6/6 - 0s - loss: 0.0013 - mse: 0.0026 - val_loss: 7.5046e-04 - val_mse: 0.0015
# Epoch 230/300
# 6/6 - 0s - loss: 0.0015 - mse: 0.0030 - val_loss: 8.0062e-04 - val_mse: 0.0016
# Epoch 231/300
# 6/6 - 0s - loss: 0.0014 - mse: 0.0028 - val_loss: 6.5717e-04 - val_mse: 0.0013
# Epoch 232/300
# 6/6 - 0s - loss: 0.0016 - mse: 0.0032 - val_loss: 8.3173e-04 - val_mse: 0.0017
# Epoch 233/300
# 6/6 - 0s - loss: 0.0017 - mse: 0.0033 - val_loss: 9.5907e-04 - val_mse: 0.0019
# Epoch 234/300
# 6/6 - 0s - loss: 0.0012 - mse: 0.0024 - val_loss: 6.2931e-04 - val_mse: 0.0013
# Epoch 235/300
# 6/6 - 0s - loss: 0.0016 - mse: 0.0031 - val_loss: 6.2965e-04 - val_mse: 0.0013
# Epoch 236/300
# 6/6 - 0s - loss: 0.0012 - mse: 0.0025 - val_loss: 6.8321e-04 - val_mse: 0.0014
# Epoch 237/300
# 6/6 - 0s - loss: 0.0014 - mse: 0.0027 - val_loss: 6.6779e-04 - val_mse: 0.0013
# Epoch 238/300
# 6/6 - 0s - loss: 0.0017 - mse: 0.0034 - val_loss: 9.0381e-04 - val_mse: 0.0018
# Epoch 239/300
# 6/6 - 0s - loss: 0.0015 - mse: 0.0030 - val_loss: 0.0027 - val_mse: 0.0055
# Epoch 240/300
# 6/6 - 0s - loss: 0.0015 - mse: 0.0031 - val_loss: 0.0010 - val_mse: 0.0021
# Epoch 241/300
# 6/6 - 0s - loss: 0.0013 - mse: 0.0025 - val_loss: 6.9709e-04 - val_mse: 0.0014
# Epoch 242/300
# 6/6 - 0s - loss: 0.0013 - mse: 0.0027 - val_loss: 6.6040e-04 - val_mse: 0.0013
# Epoch 243/300
# 6/6 - 0s - loss: 0.0012 - mse: 0.0024 - val_loss: 5.9178e-04 - val_mse: 0.0012
# Epoch 244/300
# 6/6 - 0s - loss: 0.0014 - mse: 0.0028 - val_loss: 5.8928e-04 - val_mse: 0.0012
# Epoch 245/300
# 6/6 - 0s - loss: 0.0012 - mse: 0.0024 - val_loss: 9.2910e-04 - val_mse: 0.0019
# Epoch 246/300
# 6/6 - 0s - loss: 0.0016 - mse: 0.0032 - val_loss: 5.7322e-04 - val_mse: 0.0011
# Epoch 247/300
# 6/6 - 0s - loss: 0.0013 - mse: 0.0027 - val_loss: 7.5726e-04 - val_mse: 0.0015
# Epoch 248/300
# 6/6 - 0s - loss: 0.0012 - mse: 0.0023 - val_loss: 7.2346e-04 - val_mse: 0.0014
# Epoch 249/300
# 6/6 - 0s - loss: 0.0014 - mse: 0.0028 - val_loss: 5.4680e-04 - val_mse: 0.0011
# Epoch 250/300
# 6/6 - 0s - loss: 0.0014 - mse: 0.0028 - val_loss: 5.4178e-04 - val_mse: 0.0011
# Epoch 251/300
# 6/6 - 0s - loss: 0.0012 - mse: 0.0025 - val_loss: 5.4647e-04 - val_mse: 0.0011
# Epoch 252/300
# 6/6 - 0s - loss: 0.0014 - mse: 0.0027 - val_loss: 5.4385e-04 - val_mse: 0.0011
# Epoch 253/300
# 6/6 - 0s - loss: 0.0012 - mse: 0.0025 - val_loss: 5.5909e-04 - val_mse: 0.0011
# Epoch 254/300
# 6/6 - 0s - loss: 0.0014 - mse: 0.0028 - val_loss: 5.8403e-04 - val_mse: 0.0012
# Epoch 255/300
# 6/6 - 0s - loss: 0.0013 - mse: 0.0026 - val_loss: 0.0011 - val_mse: 0.0023
# Epoch 256/300
# 6/6 - 0s - loss: 0.0012 - mse: 0.0024 - val_loss: 8.6254e-04 - val_mse: 0.0017
# Epoch 257/300
# 6/6 - 0s - loss: 0.0012 - mse: 0.0024 - val_loss: 9.9927e-04 - val_mse: 0.0020
# Epoch 258/300
# 6/6 - 0s - loss: 0.0011 - mse: 0.0023 - val_loss: 0.0011 - val_mse: 0.0022
# Epoch 259/300
# 6/6 - 0s - loss: 0.0014 - mse: 0.0029 - val_loss: 0.0014 - val_mse: 0.0028
# Epoch 260/300
# 6/6 - 0s - loss: 0.0014 - mse: 0.0028 - val_loss: 0.0011 - val_mse: 0.0021
# Epoch 261/300
# 6/6 - 0s - loss: 0.0014 - mse: 0.0028 - val_loss: 0.0011 - val_mse: 0.0022
# Epoch 262/300
# 6/6 - 0s - loss: 0.0015 - mse: 0.0030 - val_loss: 0.0016 - val_mse: 0.0032
# Epoch 263/300
# 6/6 - 0s - loss: 0.0017 - mse: 0.0034 - val_loss: 6.8579e-04 - val_mse: 0.0014
# Epoch 264/300
# 6/6 - 0s - loss: 0.0012 - mse: 0.0025 - val_loss: 5.6247e-04 - val_mse: 0.0011
# Epoch 265/300
# 6/6 - 0s - loss: 0.0011 - mse: 0.0023 - val_loss: 6.6823e-04 - val_mse: 0.0013
# Epoch 266/300
# 6/6 - 0s - loss: 0.0010 - mse: 0.0021 - val_loss: 5.2958e-04 - val_mse: 0.0011
# Epoch 267/300
# 6/6 - 0s - loss: 0.0014 - mse: 0.0028 - val_loss: 4.7499e-04 - val_mse: 9.4998e-04
# Epoch 268/300
# 6/6 - 0s - loss: 0.0013 - mse: 0.0025 - val_loss: 4.7248e-04 - val_mse: 9.4497e-04
# Epoch 269/300
# 6/6 - 0s - loss: 0.0012 - mse: 0.0023 - val_loss: 4.6809e-04 - val_mse: 9.3617e-04
# Epoch 270/300
# 6/6 - 0s - loss: 0.0011 - mse: 0.0023 - val_loss: 4.6321e-04 - val_mse: 9.2643e-04
# Epoch 271/300
# 6/6 - 0s - loss: 0.0011 - mse: 0.0022 - val_loss: 7.1709e-04 - val_mse: 0.0014
# Epoch 272/300
# 6/6 - 0s - loss: 0.0015 - mse: 0.0030 - val_loss: 4.9560e-04 - val_mse: 9.9120e-04
# Epoch 273/300
# 6/6 - 0s - loss: 0.0011 - mse: 0.0023 - val_loss: 4.5920e-04 - val_mse: 9.1841e-04
# Epoch 274/300
# 6/6 - 0s - loss: 0.0011 - mse: 0.0022 - val_loss: 5.0199e-04 - val_mse: 0.0010
# Epoch 275/300
# 6/6 - 0s - loss: 0.0012 - mse: 0.0024 - val_loss: 4.9429e-04 - val_mse: 9.8858e-04
# Epoch 276/300
# 6/6 - 0s - loss: 0.0012 - mse: 0.0024 - val_loss: 4.5034e-04 - val_mse: 9.0067e-04
# Epoch 277/300
# 6/6 - 0s - loss: 0.0011 - mse: 0.0022 - val_loss: 4.4710e-04 - val_mse: 8.9421e-04
# Epoch 278/300
# 6/6 - 0s - loss: 0.0010 - mse: 0.0021 - val_loss: 6.1602e-04 - val_mse: 0.0012
# Epoch 279/300
# 6/6 - 0s - loss: 0.0010 - mse: 0.0021 - val_loss: 8.0818e-04 - val_mse: 0.0016
# Epoch 280/300
# 6/6 - 0s - loss: 0.0012 - mse: 0.0023 - val_loss: 8.5802e-04 - val_mse: 0.0017
# Epoch 281/300
# 6/6 - 0s - loss: 0.0012 - mse: 0.0025 - val_loss: 4.5097e-04 - val_mse: 9.0193e-04
# Epoch 282/300
# 6/6 - 0s - loss: 0.0011 - mse: 0.0022 - val_loss: 4.6260e-04 - val_mse: 9.2520e-04
# Epoch 283/300
# 6/6 - 0s - loss: 0.0010 - mse: 0.0021 - val_loss: 6.5165e-04 - val_mse: 0.0013
# Epoch 284/300
# 6/6 - 0s - loss: 0.0013 - mse: 0.0025 - val_loss: 4.2626e-04 - val_mse: 8.5252e-04
# Epoch 285/300
# 6/6 - 0s - loss: 0.0011 - mse: 0.0023 - val_loss: 4.8012e-04 - val_mse: 9.6024e-04
# Epoch 286/300
# 6/6 - 0s - loss: 0.0011 - mse: 0.0022 - val_loss: 4.4520e-04 - val_mse: 8.9040e-04
# Epoch 287/300
# 6/6 - 0s - loss: 0.0012 - mse: 0.0024 - val_loss: 5.0812e-04 - val_mse: 0.0010
# Epoch 288/300
# 6/6 - 0s - loss: 0.0011 - mse: 0.0022 - val_loss: 4.4587e-04 - val_mse: 8.9175e-04
# Epoch 289/300
# 6/6 - 0s - loss: 0.0012 - mse: 0.0023 - val_loss: 4.1180e-04 - val_mse: 8.2360e-04
# Epoch 290/300
# 6/6 - 0s - loss: 0.0011 - mse: 0.0023 - val_loss: 4.5918e-04 - val_mse: 9.1835e-04
# Epoch 291/300
# 6/6 - 0s - loss: 0.0013 - mse: 0.0026 - val_loss: 4.1709e-04 - val_mse: 8.3417e-04
# Epoch 292/300
# 6/6 - 0s - loss: 0.0013 - mse: 0.0026 - val_loss: 4.2581e-04 - val_mse: 8.5162e-04
# Epoch 293/300
# 6/6 - 0s - loss: 0.0014 - mse: 0.0028 - val_loss: 6.2856e-04 - val_mse: 0.0013
# Epoch 294/300
# 6/6 - 0s - loss: 0.0016 - mse: 0.0031 - val_loss: 5.9917e-04 - val_mse: 0.0012
# Epoch 295/300
# 6/6 - 0s - loss: 0.0017 - mse: 0.0033 - val_loss: 5.0246e-04 - val_mse: 0.0010
# Epoch 296/300
# 6/6 - 0s - loss: 0.0014 - mse: 0.0029 - val_loss: 4.5511e-04 - val_mse: 9.1022e-04
# Epoch 297/300
# 6/6 - 0s - loss: 0.0012 - mse: 0.0025 - val_loss: 4.9497e-04 - val_mse: 9.8994e-04
# Epoch 298/300
# 6/6 - 0s - loss: 0.0011 - mse: 0.0023 - val_loss: 4.3116e-04 - val_mse: 8.6232e-04
# Epoch 299/300
# 6/6 - 0s - loss: 0.0014 - mse: 0.0028 - val_loss: 4.1940e-04 - val_mse: 8.3880e-04
# Epoch 300/300
# 6/6 - 0s - loss: 0.0012 - mse: 0.0023 - val_loss: 4.5352e-04 - val_mse: 9.0703e-04

# %%
#画图
plt.plot(history.history['loss'], label='train')
plt.plot(history.history['val_loss'], label='test')
plt.legend()
plt.show()

# make the prediction
yHat = model.predict(test_X)

inv_yHat = concatenate((yHat, test_x[:, 1:]), axis=1)   # 数组拼接
inv_yHat = inv_yHat[:, 0]

test_y = test_y.reshape((len(test_y), 1))
inv_y = concatenate((test_y, test_x[:, 1:]), axis=1)
inv_y = inv_y[:, 0]

rmse = sqrt(mean_squared_error(inv_yHat, inv_y))
print('Test RMSE: %.8f' % rmse)
mse = mean_squared_error(inv_yHat, inv_y)
print('Test MSE: %.8f' % mse)

yhat = model.predict(test_X)
test_X_reshaped = test_X.reshape((test_X.shape[0], test_X.shape[2]))

inv_yhat = concatenate((yhat, yhat, test_X_reshaped[:, 1:]), axis=1)
inv_yhat = inv_yhat[:, 0]
test_y = test_y.reshape((len(test_y), 1))
inv_y = concatenate((test_y, test_y, test_X_reshaped[:, 1:]), axis=1)
inv_y = inv_y[:, 0]
plt.plot(inv_yhat, label='prediction')
plt.plot(inv_y, label='real')
plt.xlabel('time')
plt.ylabel('cpu_usage_percent')
plt.legend()
plt.show()

plt.plot(inv_yhat[:500], label='prediction')
plt.plot(inv_y[:500], label='real_cpu_usage_percent')
plt.xlabel('time')
plt.ylabel('cpu_usage_percent')
plt.legend()
plt.show()

plt.plot(inv_yhat[:50], label='prediction')
plt.plot(inv_y[:50], label='real_cpu_usage_percent')
plt.xlabel('time')
plt.ylabel('cpu_usage_percent')
plt.legend()
plt.show()
# Out:
# Test RMSE: 0.03011699
# Test MSE: 0.00090703
