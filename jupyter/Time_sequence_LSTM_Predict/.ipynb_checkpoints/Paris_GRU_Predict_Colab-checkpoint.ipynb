# %%
import pandas as pd
from pandas import concat
from pandas import DataFrame
from sklearn.preprocessing import MinMaxScaler
import tensorflow as tf
import matplotlib.pyplot as plt
from numpy import concatenate
import keras
from keras.models import Sequential
from math import sqrt
from numpy import concatenate
from matplotlib import pyplot
from pandas import read_csv, datetime
from pandas import DataFrame
from pandas import concat
from sklearn.preprocessing import MinMaxScaler
from sklearn.preprocessing import LabelEncoder
from sklearn.metrics import mean_squared_error
from keras.models import Sequential
from keras.layers import Dense, Conv1D
from keras.layers import LSTM
import tensorflow as tf
import matplotlib.pyplot as plt


df = pd.read_csv('paris_data_3.csv')
temperature = df['T2M']  # centigrade
humidity = df['RH2M']  # percent
pressure = df['PS']  # Kpa
min_temp = df['T2M_MIN']
max_temp = df['T2M_MAX']
dew_temp = df['T2MDEW']
all_sky_insolation = ['ALLSKY_SFC_SW_DWN']


raw = DataFrame()
raw['ob1'] = [i for i in temperature]
raw['ob2'] = [i for i in humidity]
raw['ob3'] = [i for i in pressure]
raw['ob4'] = [i for i in min_temp]
raw['ob5'] = [i for i in max_temp]
raw['ob6'] = [i for i in dew_temp]

values = raw.values
values = values.astype('float32')
# define a function to change the data format from series to supervised-type


def change_format(data, n_in=1, n_out=1, dropnan=True):
    n_vars = 1 if isinstance(data, list) else data.shape[1]
    df = DataFrame(data)
    cols, names = list(), list()
    # input sequence (t-n, ... t-1)
    for i in range(n_in, 0, -1):
        cols.append(df.shift(i))
        names += [('var%d(t-%d)' % (j + 1, i)) for j in range(n_vars)]
    # forecast sequence (t, t+1, ... t+n)
    for i in range(0, n_out):
        cols.append(df.shift(-i))
        if i == 0:
            names += [('var%d(t)' % (j + 1)) for j in range(n_vars)]
        else:
            names += [('var%d(t+%d)' % (j + 1, i)) for j in range(n_vars)]
    # put it all together
    agg = concat(cols, axis=1)
    agg.columns = names
    # drop rows with NaN values
    if dropnan:
        agg.dropna(inplace=True)
    return agg


reframe = change_format(values, 5, 1)
reframe.drop(reframe.columns[31:36], axis=1, inplace=True)

values = reframe.values
scaler = MinMaxScaler(feature_range=(0, 1))
values = scaler.fit_transform(values)

n_train_steps = 10000
train = values[:n_train_steps, :]
test = values[n_train_steps:, :]

train_X, train_y = train[:, :-1], train[:, -1]
test_X, test_y = test[:, :-1], test[:, -1]

train_X = train_X.reshape((train_X.shape[0], 1, train_X.shape[1]))
test_X = test_X.reshape((test_X.shape[0], 1, test_X.shape[1]))

# _________________________________________________________________
model = Sequential()
model.add(Conv1D(filters=64, kernel_size=10,
                 strides=1, padding="causal",
                 activation="sigmoid"))
model.add(
    LSTM(
        64,
        input_shape=(
            train_X.shape[1],
            train_X.shape[2]),
        return_sequences=True))
model.add(LSTM(32, input_shape=(train_X.shape[1], train_X.shape[2])))
model.add(Dense(32, activation="relu"))
model.add(Dense(16, activation="relu"))
model.add(Dense(1))

model_of_temperature = model

opt = tf.keras.optimizers.Adam(lr=0.005, decay=1e-6)

model_of_temperature.compile(optimizer='Adam', loss='MAE')
h = model_of_temperature.fit(
    train_X,
    train_y,
    validation_split=0.2,
    epochs=50,
    batch_size=25)

plt.plot(h.history['loss'], label='train')

plt.plot(h.history['val_loss'], label='validation')
plt.legend()
plt.show()
# Out:
# Train on 8000 samples, validate on 2000 samples
# Epoch 1/50
# 8000/8000 [==============================] - 6s 720us/step - loss: 0.0922 - val_loss: 0.0591
# Epoch 2/50
# 8000/8000 [==============================] - 5s 608us/step - loss: 0.0479 - val_loss: 0.0548
# Epoch 3/50
# 8000/8000 [==============================] - 5s 618us/step - loss: 0.0444 - val_loss: 0.0411
# Epoch 4/50
# 8000/8000 [==============================] - 5s 619us/step - loss: 0.0420 - val_loss: 0.0372
# Epoch 5/50
# 8000/8000 [==============================] - 5s 604us/step - loss: 0.0405 - val_loss: 0.0395
# Epoch 6/50
# 8000/8000 [==============================] - 5s 609us/step - loss: 0.0392 - val_loss: 0.0431
# Epoch 7/50
# 8000/8000 [==============================] - 5s 616us/step - loss: 0.0376 - val_loss: 0.0342
# Epoch 8/50
# 8000/8000 [==============================] - 5s 612us/step - loss: 0.0385 - val_loss: 0.0389
# Epoch 9/50
# 8000/8000 [==============================] - 5s 623us/step - loss: 0.0364 - val_loss: 0.0368
# Epoch 10/50
# 8000/8000 [==============================] - 5s 616us/step - loss: 0.0369 - val_loss: 0.0355
# Epoch 11/50
# 8000/8000 [==============================] - 5s 608us/step - loss: 0.0364 - val_loss: 0.0459
# Epoch 12/50
# 8000/8000 [==============================] - 5s 610us/step - loss: 0.0362 - val_loss: 0.0354
# Epoch 13/50
# 8000/8000 [==============================] - 5s 605us/step - loss: 0.0360 - val_loss: 0.0338
# Epoch 14/50
# 8000/8000 [==============================] - 5s 611us/step - loss: 0.0364 - val_loss: 0.0351
# Epoch 15/50
# 8000/8000 [==============================] - 5s 606us/step - loss: 0.0359 - val_loss: 0.0353
# Epoch 16/50
# 8000/8000 [==============================] - 5s 602us/step - loss: 0.0347 - val_loss: 0.0327
# Epoch 17/50
# 8000/8000 [==============================] - 5s 615us/step - loss: 0.0358 - val_loss: 0.0338
# Epoch 18/50
# 8000/8000 [==============================] - 5s 611us/step - loss: 0.0353 - val_loss: 0.0321
# Epoch 19/50
# 8000/8000 [==============================] - 5s 627us/step - loss: 0.0359 - val_loss: 0.0332
# Epoch 20/50
# 8000/8000 [==============================] - 5s 597us/step - loss: 0.0346 - val_loss: 0.0352
# Epoch 21/50
# 8000/8000 [==============================] - 5s 599us/step - loss: 0.0345 - val_loss: 0.0379
# Epoch 22/50
# 8000/8000 [==============================] - 5s 612us/step - loss: 0.0343 - val_loss: 0.0363
# Epoch 23/50
# 8000/8000 [==============================] - 5s 611us/step - loss: 0.0345 - val_loss: 0.0375
# Epoch 24/50
# 8000/8000 [==============================] - 5s 609us/step - loss: 0.0341 - val_loss: 0.0315
# Epoch 25/50
# 8000/8000 [==============================] - 5s 612us/step - loss: 0.0343 - val_loss: 0.0331
# Epoch 26/50
# 8000/8000 [==============================] - 5s 617us/step - loss: 0.0345 - val_loss: 0.0329
# Epoch 27/50
# 8000/8000 [==============================] - 5s 611us/step - loss: 0.0341 - val_loss: 0.0371
# Epoch 28/50
# 8000/8000 [==============================] - 5s 591us/step - loss: 0.0352 - val_loss: 0.0450
# Epoch 29/50
# 8000/8000 [==============================] - 5s 593us/step - loss: 0.0347 - val_loss: 0.0313
# Epoch 30/50
# 8000/8000 [==============================] - 5s 612us/step - loss: 0.0340 - val_loss: 0.0312
# Epoch 31/50
# 8000/8000 [==============================] - 5s 611us/step - loss: 0.0336 - val_loss: 0.0337
# Epoch 32/50
# 8000/8000 [==============================] - 5s 611us/step - loss: 0.0339 - val_loss: 0.0315
# Epoch 33/50
# 8000/8000 [==============================] - 5s 619us/step - loss: 0.0341 - val_loss: 0.0311
# Epoch 34/50
# 8000/8000 [==============================] - 5s 612us/step - loss: 0.0341 - val_loss: 0.0315
# Epoch 35/50
# 8000/8000 [==============================] - 5s 608us/step - loss: 0.0342 - val_loss: 0.0315
# Epoch 36/50
# 8000/8000 [==============================] - 5s 600us/step - loss: 0.0341 - val_loss: 0.0332
# Epoch 37/50
# 8000/8000 [==============================] - 5s 612us/step - loss: 0.0337 - val_loss: 0.0322
# Epoch 38/50
# 8000/8000 [==============================] - 5s 611us/step - loss: 0.0338 - val_loss: 0.0323
# Epoch 39/50
# 8000/8000 [==============================] - 5s 612us/step - loss: 0.0337 - val_loss: 0.0357
# Epoch 40/50
# 8000/8000 [==============================] - 5s 614us/step - loss: 0.0338 - val_loss: 0.0309
# Epoch 41/50
# 8000/8000 [==============================] - 5s 613us/step - loss: 0.0339 - val_loss: 0.0313
# Epoch 42/50
# 8000/8000 [==============================] - 5s 617us/step - loss: 0.0336 - val_loss: 0.0328
# Epoch 43/50
# 8000/8000 [==============================] - 5s 608us/step - loss: 0.0343 - val_loss: 0.0392
# Epoch 44/50
# 8000/8000 [==============================] - 5s 606us/step - loss: 0.0339 - val_loss: 0.0313
# Epoch 45/50
# 8000/8000 [==============================] - 5s 613us/step - loss: 0.0338 - val_loss: 0.0318
# Epoch 46/50
# 8000/8000 [==============================] - 5s 625us/step - loss: 0.0332 - val_loss: 0.0332
# Epoch 47/50
# 8000/8000 [==============================] - 5s 617us/step - loss: 0.0331 - val_loss: 0.0319
# Epoch 48/50
# 8000/8000 [==============================] - 5s 615us/step - loss: 0.0339 - val_loss: 0.0368
# Epoch 49/50
# 8000/8000 [==============================] - 5s 613us/step - loss: 0.0346 - val_loss: 0.0321
# Epoch 50/50
# 8000/8000 [==============================] - 5s 620us/step - loss: 0.0328 - val_loss: 0.0333

# %%
yhat = model_of_temperature.predict(test_X)
test_X_reshaped = test_X.reshape((test_X.shape[0], test_X.shape[2]))

inv_yhat = concatenate((yhat, yhat, test_X_reshaped[:, 1:]), axis=1)
inv_yhat = scaler.inverse_transform(inv_yhat)
inv_yhat = inv_yhat[:, 0]
test_y = test_y.reshape((len(test_y), 1))
inv_y = concatenate((test_y, test_y, test_X_reshaped[:, 1:]), axis=1)
inv_y = scaler.inverse_transform(inv_y)
inv_y = inv_y[:, 0]
plt.plot(inv_yhat, label='prediction')
plt.plot(inv_y, label='real')
plt.xlabel('day')
plt.ylabel('Centigrade')
plt.legend()
plt.show()
plt.plot(inv_yhat[:100], label='prediction')
plt.plot(inv_y[:100], label='real_temperature')
plt.xlabel('day')
plt.ylabel('Centigrade')
plt.legend()
plt.show()
plt.plot(inv_yhat[:20], label='prediction')
plt.plot(inv_y[:20], label='real_temperature')
plt.xlabel('day')
plt.ylabel('Centigrade')
plt.legend()
plt.show()

# %%
from keras.layers import GRU
model = Sequential()
model.add(Conv1D(filters=64, kernel_size=10,
                 strides=1, padding="causal",
                 activation="sigmoid"))
model.add(
    GRU(
        64,
        input_shape=(
            train_X.shape[1],
            train_X.shape[2]),
        return_sequences=True))
model.add(GRU(32, input_shape=(train_X.shape[1], train_X.shape[2])))
model.add(Dense(32, activation="relu"))
model.add(Dense(16, activation="relu"))
model.add(Dense(1))

model_of_temperature = model

opt = tf.keras.optimizers.Adam(lr=0.005, decay=1e-6)

model_of_temperature.compile(optimizer='Adam', loss='MAE')
h = model_of_temperature.fit(
    train_X,
    train_y,
    validation_split=0.2,
    epochs=50,
    batch_size=25)

plt.plot(h.history['loss'], label='train')

plt.plot(h.history['val_loss'], label='validation')
plt.legend()
plt.show()
# Out:
# Train on 8000 samples, validate on 2000 samples
# Epoch 1/50
# 8000/8000 [==============================] - 7s 867us/step - loss: 0.0847 - val_loss: 0.0453
# Epoch 2/50
# 8000/8000 [==============================] - 6s 711us/step - loss: 0.0476 - val_loss: 0.0420
# Epoch 3/50
# 8000/8000 [==============================] - 6s 734us/step - loss: 0.0429 - val_loss: 0.0387
# Epoch 4/50
# 8000/8000 [==============================] - 6s 734us/step - loss: 0.0398 - val_loss: 0.0399
# Epoch 5/50
# 8000/8000 [==============================] - 6s 718us/step - loss: 0.0392 - val_loss: 0.0352
# Epoch 6/50
# 8000/8000 [==============================] - 6s 715us/step - loss: 0.0377 - val_loss: 0.0346
# Epoch 7/50
# 8000/8000 [==============================] - 6s 699us/step - loss: 0.0372 - val_loss: 0.0381
# Epoch 8/50
# 8000/8000 [==============================] - 6s 724us/step - loss: 0.0376 - val_loss: 0.0338
# Epoch 9/50
# 8000/8000 [==============================] - 6s 719us/step - loss: 0.0362 - val_loss: 0.0339
# Epoch 10/50
# 8000/8000 [==============================] - 6s 733us/step - loss: 0.0376 - val_loss: 0.0332
# Epoch 11/50
# 8000/8000 [==============================] - 6s 725us/step - loss: 0.0352 - val_loss: 0.0353
# Epoch 12/50
# 8000/8000 [==============================] - 6s 717us/step - loss: 0.0357 - val_loss: 0.0398
# Epoch 13/50
# 8000/8000 [==============================] - 6s 705us/step - loss: 0.0355 - val_loss: 0.0327
# Epoch 14/50
# 8000/8000 [==============================] - 6s 730us/step - loss: 0.0356 - val_loss: 0.0342
# Epoch 15/50
# 8000/8000 [==============================] - 6s 718us/step - loss: 0.0345 - val_loss: 0.0323
# Epoch 16/50
# 8000/8000 [==============================] - 6s 720us/step - loss: 0.0338 - val_loss: 0.0320
# Epoch 17/50
# 8000/8000 [==============================] - 6s 716us/step - loss: 0.0348 - val_loss: 0.0347
# Epoch 18/50
# 8000/8000 [==============================] - 6s 706us/step - loss: 0.0351 - val_loss: 0.0390
# Epoch 19/50
# 8000/8000 [==============================] - 6s 712us/step - loss: 0.0355 - val_loss: 0.0318
# Epoch 20/50
# 8000/8000 [==============================] - 6s 715us/step - loss: 0.0346 - val_loss: 0.0330
# Epoch 21/50
# 8000/8000 [==============================] - 6s 707us/step - loss: 0.0339 - val_loss: 0.0323
# Epoch 22/50
# 8000/8000 [==============================] - 6s 711us/step - loss: 0.0343 - val_loss: 0.0314
# Epoch 23/50
# 8000/8000 [==============================] - 6s 717us/step - loss: 0.0348 - val_loss: 0.0329
# Epoch 24/50
# 8000/8000 [==============================] - 6s 722us/step - loss: 0.0342 - val_loss: 0.0316
# Epoch 25/50
# 8000/8000 [==============================] - 6s 734us/step - loss: 0.0345 - val_loss: 0.0314
# Epoch 26/50
# 8000/8000 [==============================] - 6s 718us/step - loss: 0.0344 - val_loss: 0.0344
# Epoch 27/50
# 8000/8000 [==============================] - 6s 722us/step - loss: 0.0349 - val_loss: 0.0315
# Epoch 28/50
# 8000/8000 [==============================] - 6s 726us/step - loss: 0.0345 - val_loss: 0.0315
# Epoch 29/50
# 8000/8000 [==============================] - 6s 710us/step - loss: 0.0341 - val_loss: 0.0316
# Epoch 30/50
# 8000/8000 [==============================] - 6s 720us/step - loss: 0.0344 - val_loss: 0.0329
# Epoch 31/50
# 8000/8000 [==============================] - 6s 726us/step - loss: 0.0338 - val_loss: 0.0351
# Epoch 32/50
# 8000/8000 [==============================] - 6s 723us/step - loss: 0.0340 - val_loss: 0.0437
# Epoch 33/50
# 8000/8000 [==============================] - 6s 717us/step - loss: 0.0341 - val_loss: 0.0316
# Epoch 34/50
# 8000/8000 [==============================] - 6s 720us/step - loss: 0.0338 - val_loss: 0.0357
# Epoch 35/50
# 8000/8000 [==============================] - 6s 699us/step - loss: 0.0338 - val_loss: 0.0367
# Epoch 36/50
# 8000/8000 [==============================] - 6s 703us/step - loss: 0.0340 - val_loss: 0.0321
# Epoch 37/50
# 8000/8000 [==============================] - 6s 711us/step - loss: 0.0339 - val_loss: 0.0355
# Epoch 38/50
# 8000/8000 [==============================] - 6s 726us/step - loss: 0.0341 - val_loss: 0.0312
# Epoch 39/50
# 8000/8000 [==============================] - 6s 703us/step - loss: 0.0336 - val_loss: 0.0336
# Epoch 40/50
# 8000/8000 [==============================] - 6s 723us/step - loss: 0.0331 - val_loss: 0.0320
# Epoch 41/50
# 8000/8000 [==============================] - 6s 697us/step - loss: 0.0343 - val_loss: 0.0314
# Epoch 42/50
# 8000/8000 [==============================] - 6s 714us/step - loss: 0.0338 - val_loss: 0.0312
# Epoch 43/50
# 8000/8000 [==============================] - 6s 719us/step - loss: 0.0339 - val_loss: 0.0336
# Epoch 44/50
# 8000/8000 [==============================] - 6s 708us/step - loss: 0.0339 - val_loss: 0.0310
# Epoch 45/50
# 8000/8000 [==============================] - 6s 703us/step - loss: 0.0332 - val_loss: 0.0355
# Epoch 46/50
# 8000/8000 [==============================] - 6s 697us/step - loss: 0.0334 - val_loss: 0.0328
# Epoch 47/50
# 8000/8000 [==============================] - 5s 684us/step - loss: 0.0331 - val_loss: 0.0309
# Epoch 48/50
# 8000/8000 [==============================] - 6s 718us/step - loss: 0.0339 - val_loss: 0.0317
# Epoch 49/50
# 8000/8000 [==============================] - 6s 719us/step - loss: 0.0332 - val_loss: 0.0343
# Epoch 50/50
# 8000/8000 [==============================] - 6s 719us/step - loss: 0.0331 - val_loss: 0.0337

# %%
yhat = model_of_temperature.predict(test_X)
test_X_reshaped = test_X.reshape((test_X.shape[0], test_X.shape[2]))

inv_yhat = concatenate((yhat, yhat, test_X_reshaped[:, 1:]), axis=1)
inv_yhat = scaler.inverse_transform(inv_yhat)
inv_yhat = inv_yhat[:, 0]
test_y = test_y.reshape((len(test_y), 1))
inv_y = concatenate((test_y, test_y, test_X_reshaped[:, 1:]), axis=1)
inv_y = scaler.inverse_transform(inv_y)
inv_y = inv_y[:, 0]
plt.plot(inv_yhat, label='prediction')
plt.plot(inv_y, label='real')
plt.xlabel('day')
plt.ylabel('Centigrade')
plt.legend()
plt.show()
plt.plot(inv_yhat[:100], label='prediction')
plt.plot(inv_y[:100], label='real_temperature')
plt.xlabel('day')
plt.ylabel('Centigrade')
plt.legend()
plt.show()
plt.plot(inv_yhat[:20], label='prediction')
plt.plot(inv_y[:20], label='real_temperature')
plt.xlabel('day')
plt.ylabel('Centigrade')
plt.legend()
plt.show()

# %%
#GRU在实际表现中，相较于LSTM的loss函数更加平稳，引用方式为
#from keras.layers import GRU
#可以发现GRU和LSTM具有同样出色的结果，甚至比LSTM结果好一些。
#在很多时候，人们更愿意使用GRU来替换LSTM，因为GRU比LSTM少一个门，参数更少，相对容易训练且可以防止过拟合。
#训练样本少的时候可以使用防止过拟合，训练样本多的时候则可以节省很多训练时间。
