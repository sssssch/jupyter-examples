# %%
import matplotlib.pyplot as plt
import numpy as np
import tensorflow as tf
from tensorflow import keras
import tensorflow_datasets as tfds
tfds.disable_progress_bar()

imdb = keras.datasets.imdb

(train_data, train_labels), (test_data, test_labels) = imdb.load_data(num_words=10000)

# 一个映射单词到整数索引的词典
word_index = imdb.get_word_index()

# 保留第一个索引
word_index = {k: (v + 3) for k, v in word_index.items()}
word_index["<PAD>"] = 0
word_index["<START>"] = 1
word_index["<UNK>"] = 2  # unknown
word_index["<UNUSED>"] = 3

reverse_word_index = dict([(value, key)
                           for (key, value) in word_index.items()])

# 控制长度一致
train_data = keras.preprocessing.sequence.pad_sequences(
    train_data, value=word_index["<PAD>"], padding='post', maxlen=256)

test_data = keras.preprocessing.sequence.pad_sequences(
    test_data, value=word_index["<PAD>"], padding='post', maxlen=256)

# 输入形状是用于电影评论的词汇数目（10,000 词）
vocab_size = 10000

model = keras.Sequential()
model.add(keras.layers.Embedding(vocab_size, 16))
model.add(keras.layers.GlobalAveragePooling1D())
model.add(keras.layers.Dense(128, activation='sigmoid'))
model.add(keras.layers.Dense(1, activation='sigmoid'))

model.summary()

model.compile(optimizer='adam',
              loss='binary_crossentropy',
              metrics=['accuracy'])

# 创建validation
x_val = train_data[:10000]
partial_x_train = train_data[10000:]

y_val = train_labels[:10000]
partial_y_train = train_labels[10000:]

early_stoping = tf.keras.callbacks.EarlyStopping()

history = model.fit(partial_x_train,
                    partial_y_train,
                    epochs=40,
                    callbacks=[early_stoping],
                    batch_size=512,
                    validation_data=(x_val, y_val),
                    verbose=2)

results = model.evaluate(test_data, test_labels, verbose=2)

print(results)




# 绘图
history_dict = history.history
history_dict.keys()

acc = history_dict['accuracy']
val_acc = history_dict['val_accuracy']
loss = history_dict['loss']
val_loss = history_dict['val_loss']

epochs = range(1, len(acc) + 1)

# “bo”代表 "蓝点"
plt.plot(epochs, loss, 'bo', label='Training loss')
# b代表“蓝色实线”
plt.plot(epochs, val_loss, 'b', label='Validation loss')
plt.title('Training and validation loss')
plt.xlabel('Epochs')
plt.ylabel('Loss')
plt.legend()

plt.show()

plt.clf()   # 清除数字

plt.plot(epochs, acc, 'bo', label='Training acc')
plt.plot(epochs, val_acc, 'b', label='Validation acc')
plt.title('Training and validation accuracy')
plt.xlabel('Epochs')
plt.ylabel('Accuracy')
plt.legend()

plt.show()
# Out:
# Model: "sequential_23"
# _________________________________________________________________
# Layer (type)                 Output Shape              Param #
# =================================================================
# embedding_23 (Embedding)     (None, None, 16)          160000
# _________________________________________________________________
# global_average_pooling1d_23  (None, 16)                0
# _________________________________________________________________
# dense_61 (Dense)             (None, 128)               2176
# _________________________________________________________________
# dense_62 (Dense)             (None, 1)                 129
# =================================================================
# Total params: 162,305
# Trainable params: 162,305
# Non-trainable params: 0
# _________________________________________________________________
# Epoch 1/40
# 30/30 - 1s - loss: 0.6932 - accuracy: 0.5017 - val_loss: 0.6927 - val_accuracy: 0.4947
# Epoch 2/40
# 30/30 - 0s - loss: 0.6917 - accuracy: 0.5121 - val_loss: 0.6899 - val_accuracy: 0.5171
# Epoch 3/40
# 30/30 - 0s - loss: 0.6864 - accuracy: 0.5518 - val_loss: 0.6822 - val_accuracy: 0.7076
# Epoch 4/40
# 30/30 - 0s - loss: 0.6752 - accuracy: 0.6664 - val_loss: 0.6692 - val_accuracy: 0.6624
# Epoch 5/40
# 30/30 - 0s - loss: 0.6576 - accuracy: 0.6961 - val_loss: 0.6508 - val_accuracy: 0.6843
# Epoch 6/40
# 30/30 - 0s - loss: 0.6344 - accuracy: 0.7375 - val_loss: 0.6251 - val_accuracy: 0.7482
# Epoch 7/40
# 30/30 - 0s - loss: 0.6035 - accuracy: 0.7697 - val_loss: 0.5952 - val_accuracy: 0.7661
# Epoch 8/40
# 30/30 - 0s - loss: 0.5672 - accuracy: 0.7875 - val_loss: 0.5604 - val_accuracy: 0.7795
# Epoch 9/40
# 30/30 - 0s - loss: 0.5280 - accuracy: 0.8035 - val_loss: 0.5239 - val_accuracy: 0.7958
# Epoch 10/40
# 30/30 - 0s - loss: 0.4869 - accuracy: 0.8226 - val_loss: 0.4876 - val_accuracy: 0.8132
# Epoch 11/40
# 30/30 - 0s - loss: 0.4475 - accuracy: 0.8400 - val_loss: 0.4530 - val_accuracy: 0.8277
# Epoch 12/40
# 30/30 - 0s - loss: 0.4103 - accuracy: 0.8552 - val_loss: 0.4226 - val_accuracy: 0.8384
# Epoch 13/40
# 30/30 - 0s - loss: 0.3776 - accuracy: 0.8673 - val_loss: 0.3964 - val_accuracy: 0.8479
# Epoch 14/40
# 30/30 - 0s - loss: 0.3497 - accuracy: 0.8763 - val_loss: 0.3769 - val_accuracy: 0.8531
# Epoch 15/40
# 30/30 - 0s - loss: 0.3270 - accuracy: 0.8843 - val_loss: 0.3584 - val_accuracy: 0.8602
# Epoch 16/40
# 30/30 - 0s - loss: 0.3068 - accuracy: 0.8900 - val_loss: 0.3453 - val_accuracy: 0.8645
# Epoch 17/40
# 30/30 - 0s - loss: 0.2895 - accuracy: 0.8960 - val_loss: 0.3342 - val_accuracy: 0.8689
# Epoch 18/40
# 30/30 - 0s - loss: 0.2744 - accuracy: 0.9012 - val_loss: 0.3258 - val_accuracy: 0.8698
# Epoch 19/40
# 30/30 - 0s - loss: 0.2609 - accuracy: 0.9058 - val_loss: 0.3182 - val_accuracy: 0.8731
# Epoch 20/40
# 30/30 - 0s - loss: 0.2497 - accuracy: 0.9080 - val_loss: 0.3124 - val_accuracy: 0.8754
# Epoch 21/40
# 30/30 - 0s - loss: 0.2378 - accuracy: 0.9135 - val_loss: 0.3076 - val_accuracy: 0.8767
# Epoch 22/40
# 30/30 - 0s - loss: 0.2276 - accuracy: 0.9183 - val_loss: 0.3028 - val_accuracy: 0.8792
# Epoch 23/40
# 30/30 - 0s - loss: 0.2183 - accuracy: 0.9207 - val_loss: 0.2988 - val_accuracy: 0.8798
# Epoch 24/40
# 30/30 - 0s - loss: 0.2091 - accuracy: 0.9253 - val_loss: 0.2965 - val_accuracy: 0.8812
# Epoch 25/40
# 30/30 - 0s - loss: 0.2006 - accuracy: 0.9291 - val_loss: 0.2934 - val_accuracy: 0.8830
# Epoch 26/40
# 30/30 - 0s - loss: 0.1924 - accuracy: 0.9316 - val_loss: 0.2918 - val_accuracy: 0.8839
# Epoch 27/40
# 30/30 - 0s - loss: 0.1850 - accuracy: 0.9357 - val_loss: 0.2904 - val_accuracy: 0.8847
# Epoch 28/40
# 30/30 - 0s - loss: 0.1779 - accuracy: 0.9386 - val_loss: 0.2893 - val_accuracy: 0.8841
# Epoch 29/40
# 30/30 - 0s - loss: 0.1712 - accuracy: 0.9421 - val_loss: 0.2888 - val_accuracy: 0.8849
# Epoch 30/40
# 30/30 - 0s - loss: 0.1645 - accuracy: 0.9451 - val_loss: 0.2886 - val_accuracy: 0.8853
# Epoch 31/40
# 30/30 - 0s - loss: 0.1586 - accuracy: 0.9477 - val_loss: 0.2905 - val_accuracy: 0.8831
# 782/782 - 1s - loss: 0.3041 - accuracy: 0.8764
# [0.30409640073776245, 0.8763599991798401]
