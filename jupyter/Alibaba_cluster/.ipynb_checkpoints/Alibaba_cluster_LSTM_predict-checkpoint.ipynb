# %%
from math import sqrt
import tensorflow as tf
import pandas as pd
from keras import Sequential
from keras.layers import LSTM, Dense, Conv1D
from keras.losses import mean_squared_error
from numpy.core._multiarray_umath import concatenate
from sklearn.preprocessing import MinMaxScaler
import matplotlib.pyplot as plt

# supervised监督学习函数


def series_to_supervised(data, columns, n_in=1, n_out=1, dropnan=True):
    n_vars = 1 if isinstance(data, list) else data.shape[1]
    df = pd.DataFrame(data)
    cols, names = list(), list()
    # input sequence (t-n, ... t-1)
    for i in range(n_in, 0, -1):
        cols.append(df.shift(i))
        names += [('%s%d(t-%d)' % (columns[j], j + 1, i))
                  for j in range(n_vars)]
    # forecast sequence (t, t+1, ... t+n)
    for i in range(0, n_out):
        cols.append(df.shift(-i))
        if i == 0:
            names += [('%s%d(t)' % (columns[j], j + 1)) for j in range(n_vars)]
        else:
            names += [('%s%d(t+%d)' % (columns[j], j + 1, i))
                      for j in range(n_vars)]
    # put it all together
    agg = pd.concat(cols, axis=1)
    agg.columns = names
    # drop rows with NaN values
    if dropnan:
        clean_agg = agg.dropna()
    return clean_agg
    # return agg


dataset = pd.read_csv(
    'Machine_usage_groupby.csv')

dataset_columns = dataset.columns
values = dataset.values
print(dataset)

# 归一化处理
scaler = MinMaxScaler(feature_range=(0, 1))
scaled = scaler.fit_transform(values)


# 监督学习
reframed = series_to_supervised(scaled, dataset_columns, 1, 1)
values = reframed.values

# 学习与检测数据的划分
n_train_hours = 20000
train = values[:n_train_hours, :]
test = values[n_train_hours:, :]
print(train.shape)
print(test.shape)

# 监督学习结果划分
train_x, train_y = train[:, :-1], train[:, -1]
test_x, test_y = test[:, :-1], test[:, -1]
print(train_x.shape)
print(train_y.shape)
print(test_x.shape)
print(test_y.shape)


# 为了在LSTM中应用该数据，需要将其格式转化为3D format，即[Samples, timesteps, features]
train_X = train_x.reshape((train_x.shape[0], 1, train_x.shape[1]))
test_X = test_x.reshape((test_x.shape[0], 1, test_x.shape[1]))
print(train_X.shape)
print(test_X.shape)

model = Sequential()
model.add(Conv1D(filters=64, kernel_size=10,
                 strides=1, padding="causal",
                 activation="sigmoid"))
model.add(
    LSTM(
        64,
        input_shape=(
            train_X.shape[1],
            train_X.shape[2]),
        return_sequences=True))
model.add(LSTM(32, input_shape=(train_X.shape[1], train_X.shape[2])))
model.add(Dense(32, activation="relu"))
model.add(Dense(16, activation="relu"))
model.add(Dense(1))
model.compile(loss=tf.keras.losses.Huber(),
    optimizer='adam',
    metrics=["mae"])
history = model.fit(
    train_X,
    train_y,
    epochs=200,
    batch_size=72,
    validation_data=(
        test_X,
        test_y),
verbose = 2)
# Out:
#          Time  cpu_util_percent  ...  net_out  disk_usage_percent
# 0           0              12.0  ...    26.49                31.0
# 1         130              13.5  ...    28.63                 2.5
# 2         140               5.0  ...    18.12                 1.0
# 3         160              13.0  ...    30.09                 3.0
# 4         180               5.0  ...    18.12                 1.0
# ...       ...               ...  ...      ...                 ...
# 36211  691040              28.0  ...    41.75                 3.0
# 36212  691060              93.0  ...    38.37                 3.0
# 36213  691080              31.0  ...    35.73                 3.0
# 36214  691110              92.0  ...    38.37                 2.0
# 36215  691180              18.5  ...    38.47                 3.5
#
# [36216 rows x 8 columns]
# (20000, 16)
# (16215, 16)
# (20000, 15)
# (20000,)
# (16215, 15)
# (16215,)
# (20000, 1, 15)
# (16215, 1, 15)
# Train on 20000 samples, validate on 16215 samples
# Epoch 1/200
#  - 2s - loss: 0.0027 - mae: 0.0469 - val_loss: 0.0022 - val_mae: 0.0561
# Epoch 2/200
#  - 1s - loss: 0.0022 - mae: 0.0398 - val_loss: 0.0018 - val_mae: 0.0466
# Epoch 3/200
#  - 2s - loss: 0.0022 - mae: 0.0383 - val_loss: 0.0015 - val_mae: 0.0373
# Epoch 4/200
#  - 1s - loss: 0.0021 - mae: 0.0375 - val_loss: 0.0018 - val_mae: 0.0460
# Epoch 5/200
#  - 1s - loss: 0.0021 - mae: 0.0372 - val_loss: 0.0018 - val_mae: 0.0474
# Epoch 6/200
#  - 1s - loss: 0.0021 - mae: 0.0368 - val_loss: 0.0018 - val_mae: 0.0466
# Epoch 7/200
#  - 1s - loss: 0.0021 - mae: 0.0369 - val_loss: 0.0018 - val_mae: 0.0473
# Epoch 8/200
#  - 1s - loss: 0.0021 - mae: 0.0370 - val_loss: 0.0017 - val_mae: 0.0426
# Epoch 9/200
#  - 1s - loss: 0.0021 - mae: 0.0368 - val_loss: 0.0020 - val_mae: 0.0508
# Epoch 10/200
#  - 1s - loss: 0.0020 - mae: 0.0365 - val_loss: 0.0014 - val_mae: 0.0343
# Epoch 11/200
#  - 1s - loss: 0.0020 - mae: 0.0364 - val_loss: 0.0016 - val_mae: 0.0389
# Epoch 12/200
#  - 1s - loss: 0.0020 - mae: 0.0368 - val_loss: 0.0017 - val_mae: 0.0445
# Epoch 13/200
#  - 1s - loss: 0.0020 - mae: 0.0366 - val_loss: 0.0019 - val_mae: 0.0495
# Epoch 14/200
#  - 1s - loss: 0.0020 - mae: 0.0368 - val_loss: 0.0016 - val_mae: 0.0403
# Epoch 15/200
#  - 1s - loss: 0.0020 - mae: 0.0365 - val_loss: 0.0015 - val_mae: 0.0386
# Epoch 16/200
#  - 1s - loss: 0.0020 - mae: 0.0366 - val_loss: 0.0014 - val_mae: 0.0363
# Epoch 17/200
#  - 1s - loss: 0.0020 - mae: 0.0363 - val_loss: 0.0017 - val_mae: 0.0433
# Epoch 18/200
#  - 1s - loss: 0.0020 - mae: 0.0365 - val_loss: 0.0015 - val_mae: 0.0397
# Epoch 19/200
#  - 1s - loss: 0.0020 - mae: 0.0364 - val_loss: 0.0014 - val_mae: 0.0357
# Epoch 20/200
#  - 1s - loss: 0.0020 - mae: 0.0367 - val_loss: 0.0015 - val_mae: 0.0387
# Epoch 21/200
#  - 1s - loss: 0.0020 - mae: 0.0364 - val_loss: 0.0016 - val_mae: 0.0429
# Epoch 22/200
#  - 1s - loss: 0.0020 - mae: 0.0364 - val_loss: 0.0018 - val_mae: 0.0435
# Epoch 23/200
#  - 1s - loss: 0.0020 - mae: 0.0364 - val_loss: 0.0014 - val_mae: 0.0352
# Epoch 24/200
#  - 1s - loss: 0.0020 - mae: 0.0368 - val_loss: 0.0015 - val_mae: 0.0373
# Epoch 25/200
#  - 1s - loss: 0.0020 - mae: 0.0366 - val_loss: 0.0015 - val_mae: 0.0381
# Epoch 26/200
#  - 1s - loss: 0.0020 - mae: 0.0367 - val_loss: 0.0017 - val_mae: 0.0446
# Epoch 27/200
#  - 1s - loss: 0.0020 - mae: 0.0366 - val_loss: 0.0016 - val_mae: 0.0415
# Epoch 28/200
#  - 1s - loss: 0.0020 - mae: 0.0363 - val_loss: 0.0015 - val_mae: 0.0390
# Epoch 29/200
#  - 1s - loss: 0.0020 - mae: 0.0365 - val_loss: 0.0014 - val_mae: 0.0362
# Epoch 30/200
#  - 1s - loss: 0.0020 - mae: 0.0364 - val_loss: 0.0016 - val_mae: 0.0401
# Epoch 31/200
#  - 1s - loss: 0.0020 - mae: 0.0366 - val_loss: 0.0018 - val_mae: 0.0455
# Epoch 32/200
#  - 1s - loss: 0.0020 - mae: 0.0364 - val_loss: 0.0017 - val_mae: 0.0421
# Epoch 33/200
#  - 1s - loss: 0.0020 - mae: 0.0366 - val_loss: 0.0014 - val_mae: 0.0348
# Epoch 34/200
#  - 1s - loss: 0.0020 - mae: 0.0363 - val_loss: 0.0015 - val_mae: 0.0387
# Epoch 35/200
#  - 1s - loss: 0.0020 - mae: 0.0364 - val_loss: 0.0018 - val_mae: 0.0454
# Epoch 36/200
#  - 1s - loss: 0.0020 - mae: 0.0363 - val_loss: 0.0014 - val_mae: 0.0360
# Epoch 37/200
#  - 1s - loss: 0.0020 - mae: 0.0362 - val_loss: 0.0015 - val_mae: 0.0366
# Epoch 38/200
#  - 1s - loss: 0.0020 - mae: 0.0360 - val_loss: 0.0018 - val_mae: 0.0447
# Epoch 39/200
#  - 1s - loss: 0.0020 - mae: 0.0360 - val_loss: 0.0017 - val_mae: 0.0431
# Epoch 40/200
#  - 1s - loss: 0.0020 - mae: 0.0361 - val_loss: 0.0018 - val_mae: 0.0451
# Epoch 41/200
#  - 1s - loss: 0.0020 - mae: 0.0361 - val_loss: 0.0015 - val_mae: 0.0358
# Epoch 42/200
#  - 1s - loss: 0.0020 - mae: 0.0359 - val_loss: 0.0016 - val_mae: 0.0390
# Epoch 43/200
#  - 1s - loss: 0.0020 - mae: 0.0359 - val_loss: 0.0017 - val_mae: 0.0407
# Epoch 44/200
#  - 1s - loss: 0.0020 - mae: 0.0360 - val_loss: 0.0015 - val_mae: 0.0389
# Epoch 45/200
#  - 1s - loss: 0.0020 - mae: 0.0359 - val_loss: 0.0016 - val_mae: 0.0398
# Epoch 46/200
#  - 1s - loss: 0.0020 - mae: 0.0359 - val_loss: 0.0017 - val_mae: 0.0431
# Epoch 47/200
#  - 1s - loss: 0.0020 - mae: 0.0361 - val_loss: 0.0013 - val_mae: 0.0315
# Epoch 48/200
#  - 1s - loss: 0.0020 - mae: 0.0358 - val_loss: 0.0017 - val_mae: 0.0425
# Epoch 49/200
#  - 1s - loss: 0.0020 - mae: 0.0359 - val_loss: 0.0014 - val_mae: 0.0346
# Epoch 50/200
#  - 1s - loss: 0.0020 - mae: 0.0358 - val_loss: 0.0020 - val_mae: 0.0469
# Epoch 51/200
#  - 1s - loss: 0.0019 - mae: 0.0355 - val_loss: 0.0015 - val_mae: 0.0355
# Epoch 52/200
#  - 1s - loss: 0.0020 - mae: 0.0356 - val_loss: 0.0016 - val_mae: 0.0389
# Epoch 53/200
#  - 1s - loss: 0.0019 - mae: 0.0355 - val_loss: 0.0017 - val_mae: 0.0424
# Epoch 54/200
#  - 1s - loss: 0.0020 - mae: 0.0357 - val_loss: 0.0018 - val_mae: 0.0442
# Epoch 55/200
#  - 1s - loss: 0.0019 - mae: 0.0356 - val_loss: 0.0016 - val_mae: 0.0397
# Epoch 56/200
#  - 1s - loss: 0.0019 - mae: 0.0354 - val_loss: 0.0017 - val_mae: 0.0435
# Epoch 57/200
#  - 1s - loss: 0.0019 - mae: 0.0353 - val_loss: 0.0015 - val_mae: 0.0361
# Epoch 58/200
#  - 1s - loss: 0.0019 - mae: 0.0355 - val_loss: 0.0017 - val_mae: 0.0432
# Epoch 59/200
#  - 1s - loss: 0.0019 - mae: 0.0356 - val_loss: 0.0018 - val_mae: 0.0426
# Epoch 60/200
#  - 1s - loss: 0.0019 - mae: 0.0353 - val_loss: 0.0014 - val_mae: 0.0358
# Epoch 61/200
#  - 1s - loss: 0.0019 - mae: 0.0354 - val_loss: 0.0015 - val_mae: 0.0379
# Epoch 62/200
#  - 1s - loss: 0.0019 - mae: 0.0351 - val_loss: 0.0018 - val_mae: 0.0441
# Epoch 63/200
#  - 1s - loss: 0.0019 - mae: 0.0351 - val_loss: 0.0015 - val_mae: 0.0381
# Epoch 64/200
#  - 1s - loss: 0.0019 - mae: 0.0352 - val_loss: 0.0016 - val_mae: 0.0404
# Epoch 65/200
#  - 2s - loss: 0.0019 - mae: 0.0352 - val_loss: 0.0014 - val_mae: 0.0367
# Epoch 66/200
#  - 1s - loss: 0.0019 - mae: 0.0350 - val_loss: 0.0015 - val_mae: 0.0395
# Epoch 67/200
#  - 2s - loss: 0.0019 - mae: 0.0352 - val_loss: 0.0018 - val_mae: 0.0460
# Epoch 68/200
#  - 2s - loss: 0.0019 - mae: 0.0349 - val_loss: 0.0014 - val_mae: 0.0370
# Epoch 69/200
#  - 1s - loss: 0.0019 - mae: 0.0353 - val_loss: 0.0017 - val_mae: 0.0425
# Epoch 70/200
#  - 1s - loss: 0.0019 - mae: 0.0351 - val_loss: 0.0016 - val_mae: 0.0408
# Epoch 71/200
#  - 1s - loss: 0.0019 - mae: 0.0353 - val_loss: 0.0017 - val_mae: 0.0443
# Epoch 72/200
#  - 1s - loss: 0.0019 - mae: 0.0350 - val_loss: 0.0014 - val_mae: 0.0343
# Epoch 73/200
#  - 1s - loss: 0.0019 - mae: 0.0347 - val_loss: 0.0014 - val_mae: 0.0338
# Epoch 74/200
#  - 1s - loss: 0.0019 - mae: 0.0350 - val_loss: 0.0015 - val_mae: 0.0387
# Epoch 75/200
#  - 1s - loss: 0.0019 - mae: 0.0349 - val_loss: 0.0018 - val_mae: 0.0447
# Epoch 76/200
#  - 1s - loss: 0.0019 - mae: 0.0349 - val_loss: 0.0015 - val_mae: 0.0387
# Epoch 77/200
#  - 1s - loss: 0.0019 - mae: 0.0350 - val_loss: 0.0014 - val_mae: 0.0340
# Epoch 78/200
#  - 1s - loss: 0.0019 - mae: 0.0348 - val_loss: 0.0016 - val_mae: 0.0392
# Epoch 79/200
#  - 1s - loss: 0.0019 - mae: 0.0347 - val_loss: 0.0018 - val_mae: 0.0455
# Epoch 80/200
#  - 1s - loss: 0.0019 - mae: 0.0348 - val_loss: 0.0015 - val_mae: 0.0400
# Epoch 81/200
#  - 1s - loss: 0.0019 - mae: 0.0352 - val_loss: 0.0016 - val_mae: 0.0403
# Epoch 82/200
#  - 1s - loss: 0.0019 - mae: 0.0348 - val_loss: 0.0013 - val_mae: 0.0319
# Epoch 83/200
#  - 1s - loss: 0.0019 - mae: 0.0350 - val_loss: 0.0016 - val_mae: 0.0418
# Epoch 84/200
#  - 1s - loss: 0.0019 - mae: 0.0346 - val_loss: 0.0014 - val_mae: 0.0362
# Epoch 85/200
#  - 1s - loss: 0.0019 - mae: 0.0346 - val_loss: 0.0014 - val_mae: 0.0346
# Epoch 86/200
#  - 1s - loss: 0.0019 - mae: 0.0346 - val_loss: 0.0017 - val_mae: 0.0440
# Epoch 87/200
#  - 1s - loss: 0.0019 - mae: 0.0347 - val_loss: 0.0014 - val_mae: 0.0364
# Epoch 88/200
#  - 1s - loss: 0.0019 - mae: 0.0349 - val_loss: 0.0013 - val_mae: 0.0316
# Epoch 89/200
#  - 1s - loss: 0.0019 - mae: 0.0345 - val_loss: 0.0015 - val_mae: 0.0390
# Epoch 90/200
#  - 1s - loss: 0.0019 - mae: 0.0348 - val_loss: 0.0016 - val_mae: 0.0406
# Epoch 91/200
#  - 1s - loss: 0.0019 - mae: 0.0350 - val_loss: 0.0013 - val_mae: 0.0344
# Epoch 92/200
#  - 1s - loss: 0.0019 - mae: 0.0347 - val_loss: 0.0016 - val_mae: 0.0409
# Epoch 93/200
#  - 1s - loss: 0.0019 - mae: 0.0344 - val_loss: 0.0016 - val_mae: 0.0409
# Epoch 94/200
#  - 1s - loss: 0.0019 - mae: 0.0347 - val_loss: 0.0015 - val_mae: 0.0378
# Epoch 95/200
#  - 1s - loss: 0.0019 - mae: 0.0344 - val_loss: 0.0015 - val_mae: 0.0357
# Epoch 96/200
#  - 1s - loss: 0.0019 - mae: 0.0345 - val_loss: 0.0015 - val_mae: 0.0394
# Epoch 97/200
#  - 1s - loss: 0.0019 - mae: 0.0345 - val_loss: 0.0013 - val_mae: 0.0325
# Epoch 98/200
#  - 1s - loss: 0.0019 - mae: 0.0346 - val_loss: 0.0015 - val_mae: 0.0386
# Epoch 99/200
#  - 1s - loss: 0.0019 - mae: 0.0345 - val_loss: 0.0014 - val_mae: 0.0355
# Epoch 100/200
#  - 1s - loss: 0.0019 - mae: 0.0347 - val_loss: 0.0014 - val_mae: 0.0361
# Epoch 101/200
#  - 1s - loss: 0.0019 - mae: 0.0344 - val_loss: 0.0013 - val_mae: 0.0313
# Epoch 102/200
#  - 1s - loss: 0.0019 - mae: 0.0345 - val_loss: 0.0014 - val_mae: 0.0382
# Epoch 103/200
#  - 1s - loss: 0.0019 - mae: 0.0344 - val_loss: 0.0015 - val_mae: 0.0379
# Epoch 104/200
#  - 1s - loss: 0.0019 - mae: 0.0343 - val_loss: 0.0014 - val_mae: 0.0340
# Epoch 105/200
#  - 1s - loss: 0.0019 - mae: 0.0345 - val_loss: 0.0014 - val_mae: 0.0346
# Epoch 106/200
#  - 1s - loss: 0.0019 - mae: 0.0345 - val_loss: 0.0015 - val_mae: 0.0386
# Epoch 107/200
#  - 1s - loss: 0.0019 - mae: 0.0345 - val_loss: 0.0021 - val_mae: 0.0498
# Epoch 108/200
#  - 1s - loss: 0.0019 - mae: 0.0344 - val_loss: 0.0014 - val_mae: 0.0359
# Epoch 109/200
#  - 1s - loss: 0.0019 - mae: 0.0344 - val_loss: 0.0014 - val_mae: 0.0358
# Epoch 110/200
#  - 1s - loss: 0.0018 - mae: 0.0342 - val_loss: 0.0015 - val_mae: 0.0388
# Epoch 111/200
#  - 1s - loss: 0.0019 - mae: 0.0345 - val_loss: 0.0015 - val_mae: 0.0384
# Epoch 112/200
#  - 1s - loss: 0.0019 - mae: 0.0345 - val_loss: 0.0015 - val_mae: 0.0391
# Epoch 113/200
#  - 1s - loss: 0.0018 - mae: 0.0344 - val_loss: 0.0016 - val_mae: 0.0394
# Epoch 114/200
#  - 1s - loss: 0.0019 - mae: 0.0344 - val_loss: 0.0016 - val_mae: 0.0425
# Epoch 115/200
#  - 1s - loss: 0.0019 - mae: 0.0345 - val_loss: 0.0017 - val_mae: 0.0438
# Epoch 116/200
#  - 1s - loss: 0.0019 - mae: 0.0344 - val_loss: 0.0017 - val_mae: 0.0422
# Epoch 117/200
#  - 1s - loss: 0.0019 - mae: 0.0344 - val_loss: 0.0022 - val_mae: 0.0525
# Epoch 118/200
#  - 1s - loss: 0.0019 - mae: 0.0345 - val_loss: 0.0015 - val_mae: 0.0373
# Epoch 119/200
#  - 1s - loss: 0.0019 - mae: 0.0344 - val_loss: 0.0014 - val_mae: 0.0355
# Epoch 120/200
#  - 1s - loss: 0.0019 - mae: 0.0344 - val_loss: 0.0016 - val_mae: 0.0416
# Epoch 121/200
#  - 1s - loss: 0.0018 - mae: 0.0341 - val_loss: 0.0015 - val_mae: 0.0399
# Epoch 122/200
#  - 1s - loss: 0.0019 - mae: 0.0344 - val_loss: 0.0014 - val_mae: 0.0360
# Epoch 123/200
#  - 1s - loss: 0.0018 - mae: 0.0344 - val_loss: 0.0016 - val_mae: 0.0400
# Epoch 124/200
#  - 1s - loss: 0.0018 - mae: 0.0344 - val_loss: 0.0014 - val_mae: 0.0364
# Epoch 125/200
#  - 1s - loss: 0.0019 - mae: 0.0344 - val_loss: 0.0015 - val_mae: 0.0369
# Epoch 126/200
#  - 1s - loss: 0.0019 - mae: 0.0342 - val_loss: 0.0014 - val_mae: 0.0367
# Epoch 127/200
#  - 1s - loss: 0.0019 - mae: 0.0343 - val_loss: 0.0014 - val_mae: 0.0363
# Epoch 128/200
#  - 1s - loss: 0.0018 - mae: 0.0341 - val_loss: 0.0015 - val_mae: 0.0381
# Epoch 129/200
#  - 1s - loss: 0.0018 - mae: 0.0343 - val_loss: 0.0014 - val_mae: 0.0367
# Epoch 130/200
#  - 1s - loss: 0.0018 - mae: 0.0340 - val_loss: 0.0016 - val_mae: 0.0409
# Epoch 131/200
#  - 1s - loss: 0.0018 - mae: 0.0340 - val_loss: 0.0018 - val_mae: 0.0437
# Epoch 132/200
#  - 1s - loss: 0.0018 - mae: 0.0345 - val_loss: 0.0015 - val_mae: 0.0398
# Epoch 133/200
#  - 1s - loss: 0.0019 - mae: 0.0342 - val_loss: 0.0016 - val_mae: 0.0403
# Epoch 134/200
#  - 1s - loss: 0.0018 - mae: 0.0341 - val_loss: 0.0014 - val_mae: 0.0332
# Epoch 135/200
#  - 1s - loss: 0.0018 - mae: 0.0340 - val_loss: 0.0016 - val_mae: 0.0409
# Epoch 136/200
#  - 1s - loss: 0.0018 - mae: 0.0341 - val_loss: 0.0014 - val_mae: 0.0353
# Epoch 137/200
#  - 1s - loss: 0.0018 - mae: 0.0343 - val_loss: 0.0015 - val_mae: 0.0365
# Epoch 138/200
#  - 1s - loss: 0.0018 - mae: 0.0342 - val_loss: 0.0014 - val_mae: 0.0348
# Epoch 139/200
#  - 1s - loss: 0.0018 - mae: 0.0341 - val_loss: 0.0015 - val_mae: 0.0352
# Epoch 140/200
#  - 1s - loss: 0.0019 - mae: 0.0343 - val_loss: 0.0014 - val_mae: 0.0356
# Epoch 141/200
#  - 1s - loss: 0.0018 - mae: 0.0342 - val_loss: 0.0016 - val_mae: 0.0398
# Epoch 142/200
#  - 1s - loss: 0.0019 - mae: 0.0342 - val_loss: 0.0016 - val_mae: 0.0383
# Epoch 143/200
#  - 1s - loss: 0.0018 - mae: 0.0341 - val_loss: 0.0016 - val_mae: 0.0420
# Epoch 144/200
#  - 1s - loss: 0.0018 - mae: 0.0342 - val_loss: 0.0015 - val_mae: 0.0368
# Epoch 145/200
#  - 2s - loss: 0.0018 - mae: 0.0340 - val_loss: 0.0015 - val_mae: 0.0361
# Epoch 146/200
#  - 1s - loss: 0.0018 - mae: 0.0340 - val_loss: 0.0017 - val_mae: 0.0413
# Epoch 147/200
#  - 1s - loss: 0.0019 - mae: 0.0342 - val_loss: 0.0014 - val_mae: 0.0338
# Epoch 148/200
#  - 1s - loss: 0.0019 - mae: 0.0341 - val_loss: 0.0015 - val_mae: 0.0370
# Epoch 149/200
#  - 1s - loss: 0.0018 - mae: 0.0340 - val_loss: 0.0015 - val_mae: 0.0364
# Epoch 150/200
#  - 2s - loss: 0.0018 - mae: 0.0342 - val_loss: 0.0014 - val_mae: 0.0348
# Epoch 151/200
#  - 1s - loss: 0.0018 - mae: 0.0343 - val_loss: 0.0014 - val_mae: 0.0351
# Epoch 152/200
#  - 1s - loss: 0.0018 - mae: 0.0339 - val_loss: 0.0015 - val_mae: 0.0386
# Epoch 153/200
#  - 1s - loss: 0.0019 - mae: 0.0342 - val_loss: 0.0013 - val_mae: 0.0329
# Epoch 154/200
#  - 1s - loss: 0.0018 - mae: 0.0340 - val_loss: 0.0014 - val_mae: 0.0317
# Epoch 155/200
#  - 1s - loss: 0.0018 - mae: 0.0342 - val_loss: 0.0013 - val_mae: 0.0317
# Epoch 156/200
#  - 1s - loss: 0.0018 - mae: 0.0340 - val_loss: 0.0015 - val_mae: 0.0375
# Epoch 157/200
#  - 1s - loss: 0.0018 - mae: 0.0339 - val_loss: 0.0013 - val_mae: 0.0332
# Epoch 158/200
#  - 1s - loss: 0.0018 - mae: 0.0340 - val_loss: 0.0014 - val_mae: 0.0346
# Epoch 159/200
#  - 1s - loss: 0.0018 - mae: 0.0339 - val_loss: 0.0013 - val_mae: 0.0297
# Epoch 160/200
#  - 1s - loss: 0.0018 - mae: 0.0340 - val_loss: 0.0014 - val_mae: 0.0337
# Epoch 161/200
#  - 1s - loss: 0.0018 - mae: 0.0340 - val_loss: 0.0014 - val_mae: 0.0336
# Epoch 162/200
#  - 1s - loss: 0.0018 - mae: 0.0338 - val_loss: 0.0014 - val_mae: 0.0342
# Epoch 163/200
#  - 1s - loss: 0.0018 - mae: 0.0340 - val_loss: 0.0015 - val_mae: 0.0358
# Epoch 164/200
#  - 1s - loss: 0.0018 - mae: 0.0340 - val_loss: 0.0015 - val_mae: 0.0363
# Epoch 165/200
#  - 1s - loss: 0.0018 - mae: 0.0341 - val_loss: 0.0014 - val_mae: 0.0333
# Epoch 166/200
#  - 1s - loss: 0.0018 - mae: 0.0340 - val_loss: 0.0017 - val_mae: 0.0425
# Epoch 167/200
#  - 1s - loss: 0.0018 - mae: 0.0339 - val_loss: 0.0015 - val_mae: 0.0357
# Epoch 168/200
#  - 1s - loss: 0.0018 - mae: 0.0340 - val_loss: 0.0015 - val_mae: 0.0360
# Epoch 169/200
#  - 1s - loss: 0.0018 - mae: 0.0340 - val_loss: 0.0015 - val_mae: 0.0361
# Epoch 170/200
#  - 1s - loss: 0.0018 - mae: 0.0340 - val_loss: 0.0015 - val_mae: 0.0369
# Epoch 171/200
#  - 1s - loss: 0.0018 - mae: 0.0339 - val_loss: 0.0015 - val_mae: 0.0396
# Epoch 172/200
#  - 1s - loss: 0.0018 - mae: 0.0341 - val_loss: 0.0013 - val_mae: 0.0327
# Epoch 173/200
#  - 1s - loss: 0.0018 - mae: 0.0338 - val_loss: 0.0017 - val_mae: 0.0411
# Epoch 174/200
#  - 1s - loss: 0.0018 - mae: 0.0341 - val_loss: 0.0013 - val_mae: 0.0308
# Epoch 175/200
#  - 1s - loss: 0.0018 - mae: 0.0340 - val_loss: 0.0014 - val_mae: 0.0340
# Epoch 176/200
#  - 1s - loss: 0.0018 - mae: 0.0339 - val_loss: 0.0013 - val_mae: 0.0351
# Epoch 177/200
#  - 1s - loss: 0.0018 - mae: 0.0341 - val_loss: 0.0013 - val_mae: 0.0322
# Epoch 178/200
#  - 1s - loss: 0.0018 - mae: 0.0339 - val_loss: 0.0015 - val_mae: 0.0385
# Epoch 179/200
#  - 1s - loss: 0.0018 - mae: 0.0339 - val_loss: 0.0014 - val_mae: 0.0326
# Epoch 180/200
#  - 1s - loss: 0.0018 - mae: 0.0338 - val_loss: 0.0013 - val_mae: 0.0330
# Epoch 181/200
#  - 1s - loss: 0.0018 - mae: 0.0339 - val_loss: 0.0015 - val_mae: 0.0369
# Epoch 182/200
#  - 1s - loss: 0.0018 - mae: 0.0338 - val_loss: 0.0015 - val_mae: 0.0373
# Epoch 183/200
#  - 1s - loss: 0.0018 - mae: 0.0338 - val_loss: 0.0014 - val_mae: 0.0346
# Epoch 184/200
#  - 1s - loss: 0.0018 - mae: 0.0336 - val_loss: 0.0014 - val_mae: 0.0325
# Epoch 185/200
#  - 1s - loss: 0.0018 - mae: 0.0338 - val_loss: 0.0013 - val_mae: 0.0336
# Epoch 186/200
#  - 1s - loss: 0.0018 - mae: 0.0336 - val_loss: 0.0014 - val_mae: 0.0370
# Epoch 187/200
#  - 1s - loss: 0.0018 - mae: 0.0338 - val_loss: 0.0014 - val_mae: 0.0329
# Epoch 188/200
#  - 1s - loss: 0.0018 - mae: 0.0339 - val_loss: 0.0013 - val_mae: 0.0315
# Epoch 189/200
#  - 1s - loss: 0.0018 - mae: 0.0339 - val_loss: 0.0014 - val_mae: 0.0335
# Epoch 190/200
#  - 1s - loss: 0.0018 - mae: 0.0341 - val_loss: 0.0013 - val_mae: 0.0326
# Epoch 191/200
#  - 1s - loss: 0.0018 - mae: 0.0337 - val_loss: 0.0016 - val_mae: 0.0376
# Epoch 192/200
#  - 1s - loss: 0.0018 - mae: 0.0338 - val_loss: 0.0013 - val_mae: 0.0315
# Epoch 193/200
#  - 1s - loss: 0.0018 - mae: 0.0336 - val_loss: 0.0014 - val_mae: 0.0349
# Epoch 194/200
#  - 1s - loss: 0.0018 - mae: 0.0338 - val_loss: 0.0016 - val_mae: 0.0382
# Epoch 195/200
#  - 1s - loss: 0.0018 - mae: 0.0338 - val_loss: 0.0013 - val_mae: 0.0335
# Epoch 196/200
#  - 1s - loss: 0.0018 - mae: 0.0339 - val_loss: 0.0013 - val_mae: 0.0311
# Epoch 197/200
#  - 1s - loss: 0.0018 - mae: 0.0338 - val_loss: 0.0014 - val_mae: 0.0327
# Epoch 198/200
#  - 1s - loss: 0.0018 - mae: 0.0337 - val_loss: 0.0013 - val_mae: 0.0324
# Epoch 199/200
#  - 1s - loss: 0.0018 - mae: 0.0340 - val_loss: 0.0014 - val_mae: 0.0338
# Epoch 200/200
#  - 1s - loss: 0.0018 - mae: 0.0339 - val_loss: 0.0013 - val_mae: 0.0311

# %%
'''
    对数据绘图
'''
plt.plot(history.history['loss'], label='train')
plt.plot(history.history['val_loss'], label='test')
plt.legend()
plt.show()

# %%
# make the prediction,为了在原始数据的维度上计算损失，需要将数据转化为原来的范围再计算损失
yHat = model.predict(test_X)
print(inv_yHat.shape)

inv_yHat = concatenate((yHat, test_x[:, 1:]), axis=1)   # 数组拼接
inv_yHat = inv_yHat[:, 0]

test_y = test_y.reshape((len(test_y), 1))
inv_y = concatenate((test_y, test_x[:, 1:]), axis=1)
inv_y = inv_y[:, 0]

rmse = sqrt(mean_squared_error(inv_yHat, inv_y))
print('Test RMSE: %.3f' % rmse)
# Out:
# (16215,)
# Test RMSE: 0.051
